# %% [markdown]
# I am going to implement some of the concepts deal in this online course from Stanford University: https://www.coursera.org/learn/social-economic-networks/
#
# # Week 2
# We are going to explore
#
# - Create a real graph using the movie data!
# - Centrality
# (The concept below will be dealt in another notebook)
# - Thresholds and Phase Transitions
# - Application – Diffusion Centrality
#
# We were exploring power of graph, step by step
# We are going to use the metadata.json from https://grouplens.org/datasets/movielens/tag-genome-2021/
#
# In particular this part is the important one:
#
#
# **raw/metadata.json**
#
# The file contains information about movies from MovieLens - 84,661 lines of json objects that have the following fields:
# - title – movie title (84,484 unique titles)
# - directedBy – directors separated by comma (‘,’)
# - starring – actors separated by comma (‘,’)
# - dateAdded – date, when the movie was added to MovieLens
# - avgRating – average rating of a movie on MovieLens
# - imdbId – movie id on the IMDB website (84,661 unique ids)
# - item_id – movie id, which is consistent across files (84,661 unique ids)
# - Example line:
#
# {"title": "Toy Story (1995)", "directedBy": "John Lasseter", "starring": "Tim Allen, Tom Hanks, Don Rickles, Jim Varney,
# John Ratzenberger, Wallace Shawn, Laurie Metcalf, John Morris, R. Lee Ermey, Annie Potts", "dateAdded": null, "avgRating":
# 3.89146, "imdbId": "0114709", "item_id": 1}
#
# So what we are going to do it is to assume that all actors that appear in the same movies are connected to each other together with their director.
# This is just an interesting exercise to do. This is the first iteration, and we are going to see if we can find the "most connected actors/actresses or director" according to this metric.

# %%
import math
import networkx as nx
import matplotlib.pyplot as plt 
import numpy as np
import json
import operator
# to easily creade the connection between nodes
from itertools import combinations
# save graph
import pickle

# %%
# PARAMETERS
# min_amount_movies_to_appear_to_be_considered_in_graph
min_m = 15

# %%
# Opening JSON file
filename = 'metadata_movies.json'
# WE USE SET TO AVOID DUPLICATING THE ARTISTS
all_actors = set()
all_directors = set() 
with open(filename) as file:
    for line in file:
        json_file = json.loads(line)
        actors_list = list(json_file['starring'].replace(' ','').split(','))
        directors_list = list(json_file['directedBy'].replace(' ','').split(','))
        
        all_actors.update(actors_list)
        all_directors.update(directors_list)

# %%
print (f""" Actors in database: {len(all_actors)} and
 Directores in database: {len(all_directors)} """)
# Out:
#  Actors in database: 123048 and
#  Directores in database: 33594

# %%
json_file['starring'].replace(' ','').split(',')
# Out:
# ['SteveVaccariello',
#  'BarbaraZaun',
#  'RobBabik',
#  'BradBergman',
#  'ChristopherFragapane']

# %%
# These are too many, so we need to clean a little the data, we are going to keep the most
# this process is extremely quick :)

# %%
# WE USE DICTIONARY TO CLEAN ARTISTS WHO APPEAR IN JUST A FEW MOVIES (we see this with value)

dict_director = {}
# initiate dictionary directors
for director in list(all_directors):
    dict_director[director] = 0

# initiate actors and actresses    
dict_actors = {}
for actor in list(all_actors):
    dict_actors[actor] = 0

# %%
with open(filename) as file:
    for line in file:
        json_file = json.loads(line)
        temp_direc_list = list(json_file['directedBy'].replace(' ','').split(','))
        temp_actor_list = list(json_file['starring'].replace(' ','').split(','))

        for director in temp_direc_list:
            dict_director[director] = dict_director[director] + 1
        for actor in  temp_actor_list:
            dict_actors[actor] = dict_actors[actor] + 1

# %%
# this was an error in the dictionary
dict_actors.pop(str(""))
dict_director.pop(str(""))
# Out:
# 3153

# %%
# these are actors that appear in a lot of movies
len(set(dict_actors.values()))
# Out:
# 117

# %%
# So we are going to DELETE PEOPLE IN THE DICTIONARIES
# we do this step because we should change a dictionary while iterating it is best practice to create a new one
new_temp_actors = {k: v for k, v in dict_actors.items() if v >= min_m}
print(len(set(new_temp_actors)))
dict_actors = new_temp_actors 

new_temp_director = {k: v for k, v in dict_director.items() if v >= min_m}
dict_director  = new_temp_director
print(len(set(dict_director)))
# Out:
# 4469
# 705

# %%
# function needed to create edge easily
def rSubset(arr, r=2):
 
    return list(combinations(arr, r))

# %%
G = nx.Graph()
with open(filename) as file:
    for line in file:
        json_file = json.loads(line)
        temp_direc_list = list(json_file['directedBy'].replace(' ','').split(','))
        temp_actor_list = list(json_file['starring'].replace(' ','').split(','))
        
        clean_direct_list =[artist for artist in temp_direc_list ]
        clean_actor_list = [artist for artist in temp_actor_list ]
       
        connected_nodes = rSubset(clean_direct_list + clean_actor_list)
        for connected_node in connected_nodes:
            G.add_edge(list(connected_node)[0],list(connected_node)[1])

# %%
# Let us work with the graph that has the most important actors/actresses/directors
G0 = G.subgraph(list(dict_actors.keys())+list(dict_director.keys()))
G0

# %%
import pickle

# save graph object to file
pickle.dump(G0, open('filename.pickle', 'wb'))

# load graph object from file
G = pickle.load(open('filename.pickle', 'rb'))

# %%
def report_grahp(G):
    # max connected graph
    # GCC: dictionary that shows all the nodes that are connected
    Gcc = max(nx.connected_components(G), key=len)

    # G0: creates a subgraph with the node selected in GCC
    G0 = G.subgraph(Gcc)
    degree_sequence_sub_graph = sorted((d for n, d in G0.degree()), reverse=True)
    
    number_of_nodes = len(degree_sequence_sub_graph)
    average_connection = sum(degree_sequence_sub_graph)/number_of_nodes
    average_eccentricity = sum((list(nx.eccentricity(G0).values())))/number_of_nodes
    information_review = str(f"""Diameter: {nx.diameter(G0)}, 
                                number_of_nodes: {number_of_nodes} 
                                average_connection: {round(average_connection,2)}, 
                                average_eccentricity: {round(average_eccentricity,2)}
                                average_clustering: {round(nx.average_clustering(G0),4)}
                            """ )
                            
    return G0,information_review

# %%
G0,information_review = report_grahp(G)

# %%
print(information_review)
# Out:
# Diameter: 8,
#                                 number_of_nodes: 5125
#                                 average_connection: 88.29,
#                                 average_eccentricity: 5.66
#                                 average_clustering: 0.1817

# %% [markdown]
# Interesting we find a very high diameter giving the high connection average. And the other interesting aspects is the clustering. Personally I think is very low, considering that all that actors that appear in the same movie are all inmediately connected. So, there are actors and director that connect to others very far actors that do not connect between each other. Well maybe it is no so suprising if we think they are working together and are not necessary friends to each other.

# %%
eigenvector_centrality = nx.eigenvector_centrality(G)

# %%
eigenvector_centrality_order = dict(sorted(eigenvector_centrality.items(), key=lambda item: item[1],reverse=True))
dict_actors_order = dict(sorted(dict_actors.items(), key=lambda item: item[1],reverse=True))

# %%
eigenvector_centrality_order
# Out:
# {'SusanSarandon': 0.06733539520681518,
#  'SamuelL.Jackson': 0.06688039156625447,
#  'BruceWillis': 0.06584061166710133,
#  'ChristopherWalken': 0.06392821167638296,
#  'SteveBuscemi': 0.06304360174257274,
#  'StanleyTucci': 0.06261756862588044,
#  'NickNolte': 0.05985857585593803,
#  'DonaldSutherland': 0.058978728031788434,
#  'RobertDeNiro': 0.05788934843241732,
#  'AlecBaldwin': 0.05632475278008087,
#  'JackBlack': 0.054982062026815014,
#  'HarveyKeitel': 0.0541615617872137,
#  'WilliamH.Macy': 0.05365052454034322,
#  'JohnCusack': 0.05359852180939199,
#  'MorganFreeman': 0.05342584636450277,
#  'JohnC.Reilly': 0.05178955392270744,
#  'WoodyHarrelson': 0.0516543915929849,
#  'OliverPlatt': 0.051085685363085394,
#  'RayLiotta': 0.05102929712706255,
#  'LiamNeeson': 0.05096863746580911,
#  'JeffGoldblum': 0.05087816664502702,
#  'WillFerrell': 0.050438201946103794,
#  'BenStiller': 0.04952758781677541,
#  'OwenWilson': 0.04934117599598813,
#  'WillemDafoe': 0.04933722034920345,
#  'PaulGiamatti': 0.049255381821452435,
#  'DennisQuaid': 0.049225320347386636,
#  'NicolasCage': 0.048562125143952445,
#  'DavidKoechner': 0.048474297871622,
#  'MattDamon': 0.0483425400451432,
#  'DannyGlover': 0.04743753505802983,
#  'RobertDuvall': 0.047428772750841994,
#  'WhoopiGoldberg': 0.04730925018152313,
#  'JohnDiehl': 0.04680691863666619,
#  'JohnMalkovich': 0.04667813951003158,
#  'JulianneMoore': 0.04653945006873119,
#  'JohnLeguizamo': 0.046420644559515396,
#  'JohnGoodman': 0.046328997250760076,
#  'MichaelCaine': 0.04620652587304397,
#  'DavidCross': 0.04605118546090586,
#  'EdHarris': 0.04594365115379702,
#  'ForestWhitaker': 0.045940697388960984,
#  'BobbyCannavale': 0.04575704822592558,
#  'GaryOldman': 0.04566725318987595,
#  'JamesCaan': 0.045376309148617525,
#  "VincentD'Onofrio": 0.045191141099267244,
#  'TimRobbins': 0.04508646043817518,
#  'WinonaRyder': 0.04489416031494817,
#  'HarryDeanStanton': 0.0448610047162623,
#  'ChristopherPlummer': 0.04453610817569468,
#  'MartinSheen': 0.04440009332323218,
#  'JuliaRoberts': 0.04439828030515504,
#  'LievSchreiber': 0.044209471955528226,
#  'SamRockwell': 0.04415988597667694,
#  'JohnTurturro': 0.04382688930915378,
#  'DannyTrejo': 0.043716179953354896,
#  'TommyLeeJones': 0.04340957688046316,
#  'PhilipSeymourHoffman': 0.04321648693300592,
#  'DennisHopper': 0.04316111432739479,
#  'JohnHurt': 0.04301193646565826,
#  'DanAykroyd': 0.042957866881076834,
#  'WoodyAllen': 0.0429370839576666,
#  'RobinWilliams': 0.04290906363851691,
#  'JohnnyDepp': 0.04255724130001103,
#  'M.C.Gainey': 0.04249134297806108,
#  'PaulRudd': 0.04245706857636201,
#  'BurtReynolds': 0.042444784887088124,
#  'AnthonyHopkins': 0.04233770636578118,
#  'DustinHoffman': 0.04223178104833517,
#  'RobertDowneyJr.': 0.04223000937086012,
#  'JamesMarsden': 0.04213189877121209,
#  'AllisonJanney': 0.03695206597464772,
#  'JamesCoburn': 0.03688320665230472,
#  'RichardDreyfuss': 0.036745461016004656,
#  'BillHader': 0.03669205640463017,
#  'PeterStormare': 0.03664917014196401,
#  'UmaThurman': 0.03660280103134968,
#  'VirginiaMadsen': 0.03654209668166387,
#  'JohnTravolta': 0.03653404815675346,
#  'KieferSutherland': 0.03650791748917249,
#  'JohnLithgow': 0.03645492503854804,
#  'JoanCusack': 0.03638046513800333,
#  'BradPitt': 0.03628303658034574,
#  'SteveCarell': 0.03627189201387116,
#  'DrewBarrymore': 0.03618505714224039,
#  'NaomiWatts': 0.03610673965258145,
#  'ElliottGould': 0.03608576212176179,
#  'GinaGershon': 0.03599124142322532,
#  'JeffBridges': 0.035983691952465646,
#  'BillPullman': 0.035976217645390156,
#  'AlanArkin': 0.0359476338493267,
#  'TomHanks': 0.03587372290093625,
#  'DanHedaya': 0.03586695288788399,
#  'NicoleKidman': 0.035782868827432174,
#  'RobertPatrick': 0.03575501561038678,
#  'RonPerlman': 0.03575008871569005,
#  'MarisaTomei': 0.03568607735452601,
#  'JoePantoliano': 0.03562711107087934,
#  'GeorgeClooney': 0.03552163128421317,
#  'CubaGoodingJr.': 0.03549417205105698,
#  'WilliamHurt': 0.035427258197195485,
#  'HarrisonFord': 0.03542073874370643,
#  'MickeyRourke': 0.03530552301405169,
#  'KristenWiig': 0.035243636254115356,
#  'MichaelIronside': 0.03521586440528704,
#  'VanessaRedgrave': 0.035188000193984555,
#  'ChristianSlater': 0.03518649654001847,
#  'JudeLaw': 0.03504404661305676,
#  'EwanMcGregor': 0.035000867061859404,
#  'CateBlanchett': 0.03471740720612484,
#  'LukasHaas': 0.03466518654649605,
#  'KevinCostner': 0.034583121588845245,
#  'KevinCorrigan': 0.0345804517603814,
#  'PatrickStewart': 0.03446943910519207,
#  'JonahHill': 0.03435764495417304,
#  'JulietteLewis': 0.03431890506735096,
#  'NedBeatty': 0.034297027383414884,
#  'MatthewMcConaughey': 0.034237404172561874,
#  'SeanPenn': 0.03422157974757789,
#  'RichardGere': 0.034157144575735834,
#  'CatherineKeener': 0.03406320028071425,
#  'EthanHawke': 0.034031662051376366,
#  'JimBroadbent': 0.03402850441999217,
#  'BobBalaban': 0.03384375024644655,
#  'SteveZahn': 0.03382135708143699,
#  'SharonStone': 0.03377844359695614,
#  'ThomasLennon': 0.03376489421357952,
#  'KeanuReeves': 0.033758969836405923,
#  'CaryElwes': 0.03375249357452182,
#  'TomSizemore': 0.03365777020855846,
#  'JessicaAlba': 0.03364113279270388,
#  'BobGunton': 0.033612046500862254,
#  'JonFavreau': 0.03359644891091211,
#  'MarkRuffalo': 0.03359341824873344,
#  'EliWallach': 0.033588586944125365,
#  'BobHoskins': 0.03356424331738159,
#  'KrisKristofferson': 0.03348918117791723,
#  'RodSteiger': 0.033438136414364675,
#  'LilyTomlin': 0.033352621670396806,
#  'VincentPastore': 0.033317901162185845,
#  'PeterFalk': 0.033298888822946474,
#  'SeymourCassel': 0.033147289923447,
#  "BeverlyD'Angelo": 0.028008107812963645,
#  'BrendanFraser': 0.02800025590661871,
#  'StacyKeach': 0.02796611937364884,
#  'CarolKane': 0.027934425864169683,
#  'DannyHuston': 0.02786706986712622,
#  'RichardKind': 0.02782478980239275,
#  'RobertWagner': 0.027817532140243042,
#  'SylvesterStallone': 0.027686380687671878,
#  'JamesGandolfini': 0.02766991614524171,
#  'StephenTobolowsky': 0.02765608529434803,
#  'ScarlettJohansson': 0.02760914034388273,
#  'RenéeZellweger': 0.027601129398756398,
#  'JohnMichaelHiggins': 0.027570177958560965,
#  'PeterSarsgaard': 0.027496277733366135,
#  'MattWalsh': 0.02748449125121982,
#  'KristenBell': 0.02747852808960673,
#  'RichardE.Grant': 0.02746082377382727,
#  'JohnC.McGinley': 0.027456139793497217,
#  'RhysIfans': 0.02743798257406342,
#  'ErnestBorgnine': 0.02741080554472377,
#  'LouiseFletcher': 0.027385714992997117,
#  'JamesSpader': 0.027383122888581475,
#  'TimCurry': 0.02734966669016104,
#  'GretchenMol': 0.027330336722697527,
#  'ClancyBrown': 0.02732720618591998,
#  'MichaelRapaport': 0.02727995120907701,
#  'ChloëSevigny': 0.027257374964033,
#  'PattonOswalt': 0.027250370516924968,
#  'TimothyHutton': 0.027237805342902145,
#  'SeanConnery': 0.02723640280803168,
#  'ReeseWitherspoon': 0.027179227905186364,
#  'RyanReynolds': 0.027164093947162564,
#  'BillNighy': 0.027160606835780227,
#  'J.T.Walsh': 0.027138467901344058,
#  'ClintEastwood': 0.027131736309240678,
#  'DwayneJohnson': 0.02712779896519779,
#  'JackNicholson': 0.027116587332310694,
#  'EmmaThompson': 0.027108658143180406,
#  'StephenDorff': 0.0271002069231762,
#  'CarlaGugino': 0.027083922065728395,
#  'SandraBullock': 0.02703576985957205,
#  'JasonLee': 0.027024977910267797,
#  'EmmaStone': 0.027018432859766992,
#  'SallyKellerman': 0.027011480877296774,
#  'FredWillard': 0.027011445346929303,
#  'TomCruise': 0.02690280565727783,
#  'RichardRiehle': 0.026898201845303185,
#  'RobSchneider': 0.026849607370848246,
#  'DannyMcBride': 0.026847361207149048,
#  'WillForte': 0.02684639151413825,
#  'PhilLaMarr': 0.026717802335740892,
#  'BobOdenkirk': 0.026708045112182492,
#  'HelenHunt': 0.02670369596287396,
#  'CheechMarin': 0.02666057196743431,
#  'MayaRudolph': 0.026601735865861502,
#  'ArnoldSchwarzenegger': 0.026588624370023645,
#  'SamNeill': 0.02654674753929391,
#  'JohnRatzenberger': 0.026519464106088533,
#  'BillPaxton': 0.026475630603638774,
#  'MichaelShannon': 0.026423710580692806,
#  'ToniCollette': 0.02634383972020152,
#  'MelGibson': 0.02633049717374527,
#  'AlanCumming': 0.026310282578192273,
#  'BarryPepper': 0.026283101878103052,
#  'GriffinDunne': 0.02624139956433157,
#  'RonHoward': 0.026240547263172386,
#  'PatriciaArquette': 0.02623544856266487,
#  'BrittanyMurphy': 0.02623338698088575,
#  'BeauBridges': 0.026218660231295387,
#  'MichaelDouglas': 0.026208225759881233,
#  'ParkerPosey': 0.026184110276557135,
#  'SeanBean': 0.026164307714741618,
#  'ZooeyDeschanel': 0.026151001151013605,
#  'MaggieGyllenhaal': 0.02614406341204054,
#  'SissySpacek': 0.026139516642363313,
#  'AidanQuinn': 0.026097772882789874,
#  'JoshLucas': 0.02609728607177908,
#  'AdamSandler': 0.026093422191743168,
#  'JamesGammon': 0.026081292496796932,
#  'JessicaBiel': 0.025952973881545074,
#  'ThomasJane': 0.025932333624520958,
#  'AnnetteBening': 0.025918964309052876,
#  'HalHolbrook': 0.025892624710879407,
#  'RayWinstone': 0.02588529848304396,
#  'ColmMeaney': 0.025866439612641314,
#  'BenFoster': 0.025862440077532804,
#  'EvaMendes': 0.025852843294364138,
#  'MichaelLerner': 0.025819193780439398,
#  'KelseyGrammer': 0.025817889155470022,
#  'DavidMorse': 0.02573653576352304,
#  'ReneAuberjonois': 0.025709096121022706,
#  'BlakeClark': 0.02569299869063881,
#  'RoseByrne': 0.025673302360695073,
#  'AmandaSeyfried': 0.02562588363081418,
#  'TomBower': 0.02556626851562725,
#  'QuentinTarantino': 0.025553274843480776,
#  'IanMcShane': 0.02554462442861544,
#  'GiancarloEsposito': 0.025539498917578965,
#  'AnnaFaris': 0.02552425545605974,
#  'LaraineNewman': 0.02551427718600894,
#  'RobertCarradine': 0.025513649238603928,
#  'LinShaye': 0.025488031770819014,
#  'PruittTaylorVince': 0.025439190833923268,
#  'JohnCleese': 0.025436004031278433,
#  'SteveMartin': 0.02542435021050565,
#  'DylanBaker': 0.025417654608730696,
#  'MarcBlucas': 0.025393972248679432,
#  'RobCorddry': 0.025391359425789822,
#  'JenniferCoolidge': 0.02529024361753498,
#  'PeterDinklage': 0.0252351067337367,
#  'EthanSuplee': 0.02520899572486551,
#  'BradDourif': 0.025197417289466024,
#  'JeremyIrons': 0.025181420636975392,
#  'TedDanson': 0.02516484216710658,
#  'ShiaLaBeouf': 0.025134969202516608,
#  'OliviaWilde': 0.02509396996137478,
#  'ErnieHudson': 0.02508668314065581,
#  'JakeGyllenhaal': 0.025085945798231056,
#  'SallyKirkland': 0.025051158550184076,
#  'DennisHaysbert': 0.02504834669052712,
#  'EdBegleyJr.': 0.025015657250319717,
#  'PowersBoothe': 0.02491531863150995,
#  'StellanSkarsgård': 0.024862228766148124,
#  'JenaMalone': 0.024843697072192784,
#  'KateBeckinsale': 0.024834279167130366,
#  'MollyShannon': 0.024811919350648755,
#  'KimBasinger': 0.024709385058645686,
#  'OliverStone': 0.02470245288072628,
#  'AdamScott': 0.024701138293390334,
#  'EdHelms': 0.0246868233670699,
#  'CraigRobinson': 0.024623933814118416,
#  'PierceBrosnan': 0.02461738039771658,
#  'CarolineAaron': 0.024610442946248173,
#  'RichardSchiff': 0.024552042205612842,
#  'KathyBaker': 0.024545327435568205,
#  'GarySinise': 0.024539063067693243,
#  'GerardButler': 0.024528679646050322,
#  'JamesRemar': 0.024488860538829288,
#  'BarbaraHershey': 0.02448716635887994,
#  'IlleanaDouglas': 0.024483749905067482,
#  'OrlandoBloom': 0.024396467920474743,
#  'EugeneLevy': 0.02439556182313929,
#  'WilliamSadler': 0.024356312465703415,
#  'WesleySnipes': 0.02435281625297352,
#  'RosiePerez': 0.02432650632570462,
#  'WaltonGoggins': 0.024315525692509315,
#  'BlytheDanner': 0.024305081789744252,
#  'JasonSudeikis': 0.02429841538631263,
#  'ShirleyMacLaine': 0.02427821962481439,
#  'WillPatton': 0.02426526018804114,
#  'EmilyMortimer': 0.024244978149005968,
#  'DavidArquette': 0.02423885463527366,
#  'PeterBoyle': 0.02423873373723751,
#  'JudiDench': 0.024232481847851896,
#  'JonPolito': 0.024220521868984744,
#  'RachelWeisz': 0.0241776789327054,
#  'MartinStarr': 0.024158208738922677,
#  'EdwardHerrmann': 0.024131296526254304,
#  'ArmandAssante': 0.024106736568842723,
#  'JenniferTilly': 0.02401898172520793,
#  'RobReiner': 0.023965093854638013,
#  'MelissaLeo': 0.023958349639708523,
#  'MatthewLillard': 0.02395687053751231,
#  'ClarkGregg': 0.023911388632700672,
#  'JenniferConnelly': 0.023891878042812863,
#  'BenjaminBratt': 0.023822979698674966,
#  'DonaldPleasence': 0.02379834129981849,
#  'DennisFarina': 0.023793848143923393,
#  'JohnCarrollLynch': 0.023766940667698074,
#  'DonalLogue': 0.023752284611284674,
#  'CedrictheEntertainer': 0.02373151791918332,
#  'MiguelFerrer': 0.02372103945853872,
#  'MarkStrong': 0.023713515790908135,
#  'JonHamm': 0.02370424290134456,
#  'KimCoates': 0.023673882632279125,
#  'CleaDuVall': 0.023640954509681147,
#  'DavidCarradine': 0.023633202198861506,
#  'ChloëGraceMoretz': 0.02362389860444192,
#  'ChazzPalminteri': 0.023589181635110118,
#  'DianeKeaton': 0.023587253819426283,
#  'RidleyScott': 0.023580606974208287,
#  'YulVazquez': 0.023574903473391935,
#  'AaronEckhart': 0.023567458489644526,
#  'SydneyPollack': 0.02356480746971553,
#  'AshleyJudd': 0.0234940764911196,
#  'JamesBelushi': 0.02348635414445317,
#  'DavidPaymer': 0.023377008096326875,
#  'DavidThewlis': 0.023372689246252607,
#  'GlenneHeadly': 0.023360686531888664,
#  'ChrisEvans': 0.02335710095676055,
#  'IsabellaRossellini': 0.0233186392164814,
#  'SarahSilverman': 0.023317391315075993,
#  'DannyAiello': 0.0232916170115857,
#  'RussellCrowe': 0.02328743317784835,
#  'MartinShort': 0.023281810740348786,
#  'ThomasKretschmann': 0.023274202325599545,
#  'KenJeong': 0.023273671417322384,
#  'AnthonyMackie': 0.023271101871814505,
#  'AnthonyLaPaglia': 0.023255759487467206,
#  'JamesRebhorn': 0.023253560390194064,
#  'JohnLarroquette': 0.023227812540755788,
#  'DavidSchwimmer': 0.023209515798788573,
#  'JamieKennedy': 0.023171233976571406,
#  'RadeSerbedzija': 0.02313510097705833,
#  'Mary-LouiseParker': 0.02313130869409744,
#  'PaulNewman': 0.02312569918853729,
#  'CatherineZeta-Jones': 0.023093015618800665,
#  'DianneWiest': 0.023091070385430484,
#  'LucyLiu': 0.020406290544127837,
#  'ChristopherMintz-Plasse': 0.020387601158772747,
#  'BillyCrystal': 0.020372469308406558,
#  'PaulDano': 0.020368483376950967,
#  'JayMohr': 0.020339451134083905,
#  'DiedrichBader': 0.020338588544682977,
#  'DylanMcDermott': 0.02029309718266304,
#  'TomArnold': 0.02025794683225334,
#  'AshtonKutcher': 0.020256465455680266,
#  'FrancesFisher': 0.020250840610936367,
#  'AnneBancroft': 0.0202505187682401,
#  'StephenLang': 0.020244987269716824,
#  'RichardPortnow': 0.020213951177001095,
#  'DavidSpade': 0.020153384368877415,
#  'MarleyShelton': 0.020152141012978513,
#  'JudyDavis': 0.020136727690451002,
#  'MaryElizabethWinstead': 0.020128068500428666,
#  'ZachGalifianakis': 0.02012497369530203,
#  'MichaelBowen': 0.020076116388930955,
#  'TobeyMaguire': 0.020075799042138055,
#  'StephenBaldwin': 0.020063545481307635,
#  'UdoKier': 0.020056069366275936,
#  'MillaJovovich': 0.020052923708855253,
#  'GeorgeLopez': 0.020048588015215026,
#  'JasonAlexander': 0.02001875101797716,
#  'JasonPatric': 0.020013699205713737,
#  'JoePesci': 0.019975481363058704,
#  'AndyRichter': 0.019970786013897977,
#  'MenaSuvari': 0.019961198099178422,
#  'AbigailBreslin': 0.019946542481492472,
#  'EddieIzzard': 0.019925076375258675,
#  'IdrisElba': 0.019885654254701554,
#  'LarryMiller': 0.019881836612519386,
#  'TimothySpall': 0.01985717994373095,
#  'SaulRubinek': 0.019844515659985122,
#  'MichaelBiehn': 0.019831084837820676,
#  'ChrisPratt': 0.01983038013087964,
#  'EdwardAsner': 0.019828701716210276,
#  'MaxPerlich': 0.019812613419969777,
#  'RobertMitchum': 0.019797164117246486,
#  'ChristopherMeloni': 0.019774064327561767,
#  'JunoTemple': 0.019773493935347004,
#  'RobRiggle': 0.01975624274104938,
#  'MinnieDriver': 0.019748467524132614,
#  'RashidaJones': 0.019739193913574732,
#  'EmilyBlunt': 0.01972718275257063,
#  'AngelaBassett': 0.01970596571625114,
#  'WilliamShatner': 0.019653457937547376,
#  'KellyPreston': 0.019646584771152716,
#  'ClaireForlani': 0.019639185762131896,
#  'VeraFarmiga': 0.019636579613036543,
#  'ScottCaan': 0.019630273410703572,
#  'MiloVentimiglia': 0.019610917776643446,
#  'JudahFriedlander': 0.019583515042420424,
#  'FredArmisen': 0.019575594150118787,
#  'GarryMarshall': 0.019560943163793698,
#  'Jr.': 0.019537867000473507,
#  'MichelleWilliams': 0.019533679446645833,
#  'ShaunToub': 0.019522343642955558,
#  'MikeMyers': 0.019518968660701665,
#  'ShawnHatosy': 0.01949719575476071,
#  'DakotaFanning': 0.019484445365941943,
#  'GeoffreyRush': 0.01948442316443657,
#  'JaredHarris': 0.01946133394279637,
#  'HarlandWilliams': 0.01944367836336049,
#  'JeanneTripplehorn': 0.01944348703390755,
#  'JasonFlemyng': 0.01943879679476057,
#  'BradleyWhitford': 0.01938819240736827,
#  'PenelopeAnnMiller': 0.01937065190190456,
#  'JeffFahey': 0.016697919316989246,
#  'GusVanSant': 0.016683393336506824,
#  'CampbellScott': 0.01667312509889803,
#  'RichardBenjamin': 0.016671705887616052,
#  'AmyIrving': 0.016654299297031633,
#  'LoisSmith': 0.01665334117080513,
#  'JohnFarley': 0.016645678738298145,
#  'JoelCoen': 0.01663600721264072,
#  'EmbethDavidtz': 0.016628013207543424,
#  'MauryChaykin': 0.016620906443698093,
#  'VivicaA.Fox': 0.0165734916613549,
#  'KathyGriffin': 0.01657179621450485,
#  'NoelGugliemi': 0.016547086298880794,
#  'CurtisArmstrong': 0.01654022152088673,
#  'CandiceBergen': 0.016538269385473814,
#  'CharlesFleischer': 0.01650974713310852,
#  'KellyLynch': 0.016495971074642873,
#  'IceCube': 0.01646620201033401,
#  'KristenSchaal': 0.016459927298054063,
#  'MikeNichols': 0.01644250623054224,
#  'RupertEverett': 0.01642740272883661,
#  'NickCannon': 0.016427103562842223,
#  'JenniferBeals': 0.01639977768472374,
#  ...}

# %%
# this was the actress more well connected giving this metric, what do you think?
nx.node_connected_component(G, 'SusanSarandon')
# Out:
# {'FrankMorgan',
#  'DonDeFore',
#  'TimThomerson',
#  'NicolasDuvauchelle',
#  'MichaelAnsara',
#  'DickMiller',
#  'AndrewSensenig',
#  'JeanSorel',
#  'HoltMcCallany',
#  'PeterHaber',
#  'MichelSimon',
#  'JackHawkins',
#  'ArchieMayo',
#  'DevonBostick',
#  'MarioCarotenuto',
#  'DonStroud',
#  'JohnAshton',
#  'JohnRussell',
#  'GeoffreyKeen',
#  'JohnSaxon',
#  'MichaelPate',
#  'D.B.Sweeney',
#  'StanleyTucci',
#  'MelindaDillon',
#  'CharlesMcGraw',
#  'LamChing-Ying',
#  'JamesGammon',
#  'JessicaChastain',
#  'CharlesJarrott',
#  'SteveAustin',
#  'SeanPatrickFlanery',
#  'IanMcShane',
#  'MortenGrunwald',
#  'TomokazuSeki',
#  'FredArmisen',
#  'VincentElbaz',
#  'SamTaylor',
#  'VingRhames',
#  'SylvesterStallone',
#  'ElvisPresley',
#  'EricBalfour',
#  'ElinaLöwensohn',
#  'RichardRoundtree',
#  'FrankCapra',
#  'DannyMcBride',
#  'AlisonBrie',
#  'CarloLizzani',
#  'A.J.Buckley',
#  'ChristinaCox',
#  'JohnWayne',
#  'ElizabethDaily',
#  'KateBurton',
#  'JohnAmos',
#  'VivicaA.Fox',
#  'TreatWilliams',
#  'DouglasJackson',
#  'LaurieMetcalf',
#  'WarwickDavis',
#  'RobertPattinson',
#  'RickMoranis',
#  'JohnHurt',
#  'JoshuaJackson',
#  'NagisaÔshima',
#  'KjellBergqvist',
#  'ChesterMorris',
#  'MasakiKobayashi',
#  'AlexisSmith',
#  "MargaretO'Brien",
#  'AlanJ.Pakula',
#  'RichardNg',
#  'AnitaPage',
#  'AïssaMaïga',
#  'CiccioIngrassia',
#  'FranciscoRabal',
#  'OliviaHussey',
#  'JeanneMoreau',
#  'RobinGivens',
#  'ViktorSukhorukov',
#  'AdrianPaul',
#  'RoscoeKarns',
#  'MartinCompston',
#  'WilliamSmith',
#  'LeslieBibb',
#  'AjayDevgan',
#  'HardyKrüger',
#  'AitanaSánchez-Gijón',
#  'AndreBraugher',
#  'ChristinaApplegate',
#  'SergiLópez',
#  'OlympiaDukakis',
#  'AnneFrancis',
#  'GordonLiuChia-Hui',
#  'HarryConnickJr.',
#  'SergeiMakovetsky',
#  'J.CarrolNaish',
#  'DollyParton',
#  'PatriceLeconte',
#  'PhilippedeBroca',
#  'AnnaPaquin',
#  'SidHaig',
#  'BradRenfro',
#  'MarkDamon',
#  'ScottSpeedman',
#  'HenryKoster',
#  'RomolaGarai',
#  'RosannaArquette',
#  'OliverPlatt',
#  'MichaelNouri',
#  'BipashaBasu',
#  'FrankieAvalon',
#  'KeoniWaxman',
#  'RichardDysart',
#  'MariaGraziaCucinotta',
#  'StephenLang',
#  'TippiHedren',
#  'LinaRomay',
#  'SungKang',
#  'GeraldMohr',
#  'RobertHossein',
#  'RobertAldrich',
#  'M.C.Gainey',
#  'NicholasHoult',
#  'ÁngelaMolina',
#  'LouisLumière',
#  'JürgenProchnow',
#  'BarbaraCrampton',
#  'KellyReilly',
#  'DavidArquette',
#  'ErnestR.Dickerson',
#  'EricStoltz',
#  'RobertPatrick',
#  'JonasKarlsson',
#  'AnnDowd',
#  'MekhiPhifer',
#  'PhilipBakerHall',
#  'FranklinJ.Schaffner',
#  'IrinaKupchenko',
#  'OwenWilson',
#  'LeVarBurton',
#  'LenCariou',
#  'JavierBardem',
#  'AngelinaJolie',
#  'RandyCouture',
#  'PatrickChesnais',
#  'HarryBelafonte',
#  'MichaelRooker',
#  'BillyDrago',
#  'OttoPreminger',
#  'HenryThomas',
#  'MichaelLandes',
#  'DavidSpade',
#  'RandolphScott',
#  'JacquesVilleret',
#  'AaronAshmore',
#  'JordiMollà',
#  'JohnMalkovich',
#  'MattDillon',
#  'TuesdayWeld',
#  'PriyankaChopra',
#  'ZooeyDeschanel',
#  'MarthaHyer',
#  'FranKranz',
#  'FrankReicher',
#  'AdrienneBarbeau',
#  'AlluArjun',
#  'PeterMarkle',
#  'GriffinDunne',
#  'RudolfHrušínský',
#  'AnneParillaud',
#  'JohnForsythe',
#  'KenDavitian',
#  'LeslieCheung',
#  'RosannaSchiaffino',
#  'ShannonHartman',
#  'CoreySevier',
#  'JeremyIrons',
#  'WuMa',
#  'UnaMerkel',
#  'RingoLam',
#  'W.C.Fields',
#  'CecilB.DeMille',
#  'MyrnaLoy',
#  'GuyKibbee',
#  'DaneDeHaan',
#  'RobertNewton',
#  'ChulpanKhamatova',
#  'ClaudeDauphin',
#  'MarcelloMastroianni',
#  'RhodaGriffis',
#  'NickCannon',
#  'DavidBowie',
#  'AnnDoran',
#  'RichardTyson',
#  'RichardBasehart',
#  'DonJohnson',
#  'JohnOrtiz',
#  'ClaudioBisio',
#  'EdwardArnold',
#  'DickForan',
#  'DavidManners',
#  'JaneRussell',
#  'LouCastel',
#  'TedRaimi',
#  'StacyMartin',
#  'ClaireForlani',
#  'NathanielParker',
#  'AsiaArgento',
#  'EddieMarsan',
#  'IreneDunne',
#  'LenaHeadey',
#  'RaeDawnChong',
#  'RachelMcAdams',
#  'EmmanuelleBéart',
#  'EmmanuelleDevos',
#  'LubnaAzabal',
#  'ElliottGould',
#  'MollyShannon',
#  'BillCosby',
#  'MichaelMcKean',
#  'DavidWenham',
#  'RamzyBedia',
#  'TaissaFarmiga',
#  'JackieCooper',
#  'CharlesLamont',
#  'GuyMarchand',
#  'MarioVanPeebles',
#  'SidneyLumet',
#  'WesBentley',
#  'AndyRichter',
#  'FelicityJones',
#  'JeanneTripplehorn',
#  'JoelMcCrea',
#  'RitaTushingham',
#  'SebastianCabot',
#  'LouTaylorPucci',
#  'JasmineTrinca',
#  'JeanDebucourt',
#  'RalphBellamy',
#  'JulienTemple',
#  'BrigitteBardot',
#  'DavidLynch',
#  'JohnFord',
#  'BuddyEbsen',
#  'JoanFontaine',
#  'DaveFleischer',
#  'UliEdel',
#  'DonCheadle',
#  'WilfridHyde-White',
#  'Jean-FrançoisStévenin',
#  'RobertPine',
#  'JeffreyDeanMorgan',
#  'NedBellamy',
#  'LilyCollins',
#  'GeorgeArchainbaud',
#  'YulBrynner',
#  'BobOdenkirk',
#  'AnthonyLaPaglia',
#  'ZoëKravitz',
#  'MichaelRispoli',
#  'RoseByrne',
#  'ClovisCornillac',
#  'RichardLinklater',
#  'RobLowe',
#  'JürgenVogel',
#  'SinéadCusack',
#  'PeterJason',
#  'CirioH.Santiago',
#  'SaïdTaghmaoui',
#  'WilliamFriedkin',
#  'DonMichaelPaul',
#  'MartinStarr',
#  'LesliePhillips',
#  'SalvatoreSamperi',
#  'BoHopkins',
#  'TraceyUllman',
#  'Vesa-MattiLoiri',
#  'ColeHauser',
#  'CaroleBouquet',
#  'JemaineClement',
#  'CaterinaMurino',
#  'MarioCasas',
#  'JohnHough',
#  'LauraLinney',
#  'TedMcGinley',
#  'ShiriAppleby',
#  'RuthHussey',
#  'KôjiYakusho',
#  'BrendaBlethyn',
#  'RobertMitchum',
#  'DennisQuaid',
#  'KellyMacdonald',
#  'AllanEdwall',
#  'TonyGoldwyn',
#  'PollyWalker',
#  'GeorgeMontgomery',
#  'EduardoFajardo',
#  'RolandCulver',
#  'JudeLaw',
#  'GadElmaleh',
#  'MaikaMonroe',
#  'ChevyChase',
#  'NeilPatrickHarris',
#  'HenryKing',
#  'EliasKoteas',
#  'EvgeniyEvstigneev',
#  'TilSchweiger',
#  'ImanolArias',
#  'JamesFaulkner',
#  'FabioTesti',
#  'JayChapman',
#  'CamrynManheim',
#  'DustinHoffman',
#  'MarciaGayHarden',
#  'CalebLandryJones',
#  'VincentPrice',
#  'TeruyukiKagawa',
#  'KevinHart',
#  'CiaránHinds',
#  'EdwardZwick',
#  'LaurenBacall',
#  'MickeyRooney',
#  'BeverlyGarland',
#  'ChesterConklin',
#  'PaulScofield',
#  'SamanthaMorton',
#  'HaydenPanettiere',
#  'GordonDouglas',
#  'CoreyYuen',
#  'DanStevens',
#  'MiaKirshner',
#  'BillNunn',
#  'PaulGiamatti',
#  'LeeTergesen',
#  'GrahamGreene',
#  'GlendaJackson',
#  'RennyHarlin',
#  'EleonoraRossiDrago',
#  'TimothyOlyphant',
#  'DanDuryea',
#  'HumphreyBogart',
#  'KennethTobey',
#  'JodieWhittaker',
#  'EricRoberts',
#  'YuenBiao',
#  'TommyChong',
#  'JasonSchwartzman',
#  'BobHoskins',
#  'LeoMcCarey',
#  'BoDerek',
#  'CharismaCarpenter',
#  'JeanNegulesco',
#  'BertrandTavernier',
#  'CasperVanDien',
#  'JoaquinPhoenix',
#  'PeterSellers',
#  'ShelleyWinters',
#  'HarryMorgan',
#  'TomWaits',
#  'PhilippeGarrel',
#  'SylviaSyms',
#  'SeanFaris',
#  'RaquelWelch',
#  'ShirleyKnight',
#  'LanceReddick',
#  'ClaudioAmendola',
#  'PeterFirth',
#  'KayWalsh',
#  'CécileDeFrance',
#  'AlexisBledel',
#  'GaryBusey',
#  'LeslieBanks',
#  'KellyRutherford',
#  'AndyOn',
#  'TiffanyShepis',
#  'GuyMadison',
#  'AndrewStevens',
#  'VirginiaGrey',
#  'EddieConstantine',
#  'GladysGeorge',
#  'BoSvenson',
#  'MaeQuestel',
#  'YoshikoKuga',
#  'IrinaBjörklund',
#  'ReginaldOwen',
#  'MickJackson',
#  'RhonaMitra',
#  'RichardAttenborough',
#  'CatherineMaryStewart',
#  'MitchellLeisen',
#  'RoyBoulting',
#  'GuguMbatha-Raw',
#  'EnnioFantastichini',
#  'TommyLeeJones',
#  'SimónAndreu',
#  'HelenMcCrory',
#  'ErikaChristensen',
#  'DrewBarrymore',
#  'PaulWilliams',
#  'PaulWalker',
#  'RaimondoVianello',
#  'MarkL.Lester',
#  'JoanBlondell',
#  'DarioArgento',
#  'JohnHeard',
#  'AntonioResines',
#  'SylviaChang',
#  'TimRoth',
#  'VictorMcLaglen',
#  'IreneHervey',
#  'JohnGielgud',
#  'VincentMacaigne',
#  'MischaAuer',
#  'NivinPauly',
#  'ElizabethPerkins',
#  'JerryJameson',
#  'PatriciaClarkson',
#  'EdmundGwenn',
#  'DonGordon',
#  'KathleenRobertson',
#  'RhysIfans',
#  'BrendanFehr',
#  'MiriamMargolyes',
#  'JoelDavidMoore',
#  'AnnaGaliena',
#  'JohnnyCash',
#  'JasonFlemyng',
#  'MichaelWincott',
#  'KouichiYamadera',
#  'LizaMinnelli',
#  'SallyField',
#  'AndyDick',
#  'JohnFrankenheimer',
#  'MichaelBiehn',
#  'IanHart',
#  'WilWheaton',
#  'JaneWyman',
#  'BrianDennehy',
#  'Ann-Margret',
#  'AmericaFerrera',
#  'JoanCusack',
#  'PierceBrosnan',
#  'TracyMorgan',
#  'ÓscarJaenada',
#  'ClydeGeronimi',
#  'GeraldThomas',
#  'MariaBonnevie',
#  'RosemaryDeCamp',
#  'JohnAstin',
#  'Mako',
#  'ErnieHudson',
#  'SimonPhillips',
#  'ArmandMastroianni',
#  'VincentRegan',
#  'JacquesWeber',
#  'IbenHjejle',
#  'ChuckNorris',
#  'ChazzPalminteri',
#  'StuartGillard',
#  'ConradVeidt',
#  'RichardLynch',
#  'RafeSpall',
#  'ScottBakula',
#  'AkiraKamiya',
#  'KateReid',
#  'FrankWolff',
#  'BalthazarGetty',
#  'RichardBrooks',
#  'Ice-T',
#  'AndréMorell',
#  'JohnGilbert',
#  'LouisGarrel',
#  'ZoeKazan',
#  'BrigitteNielsen',
#  'HugoFregonese',
#  'ClaireTrevor',
#  'JeanetteMacDonald',
#  'JerryStiller',
#  'DavidWinning',
#  'HowardRoss',
#  'WesAnderson',
#  'JosephSargent',
#  'FredWilliamson',
#  'JoshLucas',
#  'AlexNicol',
#  'JessWeixler',
#  'KaleyCuoco',
#  'GeorgeBarbier',
#  'DavidKrumholtz',
#  'SeannWilliamScott',
#  'IsabelleAdjani',
#  'FrançoiseFabian',
#  'DamianLewis',
#  'GeorgeHamilton',
#  'GeorgeHarrison',
#  'Nayanthara',
#  'DamianoDamiani',
#  'JoanLeslie',
#  'HopeLange',
#  'EddieMurphy',
#  'NancyAllen',
#  'JimVarney',
#  'JeanneBalibar',
#  'AlexandraPaul',
#  'AnneHathaway',
#  'BrettHalsey',
#  'CharlesFleischer',
#  'BrunoMattei',
#  'DouglasSirk',
#  'EdwardG.Robinson',
#  'MaggieGyllenhaal',
#  'VasiliyLivanov',
#  'BarbaraHale',
#  'AdolpheMenjou',
#  'RussTamblyn',
#  'FrancoNero',
#  'BulleOgier',
#  'BenCross',
#  'FrancoFranchi',
#  'DanielPetrie',
#  'JeffreyWright',
#  'WilliamCastle',
#  'HedyLamarr',
#  'MaryBoland',
#  'JaredHarris',
#  'GiuseppeBattiston',
#  'AnnDvorak',
#  'RaymondMassey',
#  'CliveRevill',
#  'WilliamA.Seiter',
#  'JeffFahey',
#  'ChristopherPlummer',
#  'JohnCromwell',
#  'LanceBangs',
#  'BrianBlessed',
#  'JosephRuben',
#  'RitaHayworth',
#  'AndréDussollier',
#  'MarkHamill',
#  'TakashiMiike',
#  'DarylHannah',
#  'WillForte',
#  'ChrisMarquette',
#  'TaharRahim',
#  'RonEldard',
#  'JackBenny',
#  'NickChinlund',
#  'IdaLupino',
#  'MariyaVinogradova',
#  'TayeDiggs',
#  'JeffKober',
#  'JacquesDutronc',
#  'EttoreManni',
#  'YuriyKutsenko',
#  'TimHolt',
#  'IsaachDeBankolé',
#  'AliciaSilverstone',
#  'PeterBerg',
#  'OmarSy',
#  'MartinSheen',
#  'AdamDriver',
#  'MikeTyson',
#  'AnatoleLitvak',
#  'CharlesMartinSmith',
#  'LindsayWagner',
#  'SatoshiTsumabuki',
#  'HelenTwelvetrees',
#  'LouisGossettJr.',
#  'ForestWhitaker',
#  'ScottBrady',
#  'LeeH.Katzin',
#  'TomGreen',
#  'DominiquePinon',
#  'AustinPendleton',
#  'StuartRosenberg',
#  'DelbertMann',
#  'JeanYanne',
#  'DavidHydePierce',
#  'Jean-LucGodard',
#  'RobSchneider',
#  'KennethBranagh',
#  'WilliamLundigan',
#  'HeikkiKinnunen',
#  'MassimoBoldi',
#  'GreydonClark',
#  'MikioNaruse',
#  'AliLarter',
#  'MichaelIanBlack',
#  'EmilJannings',
#  'DanielleDarrieux',
#  'DiedrichBader',
#  'MinnieDriver',
#  'KeyeLuke',
#  'CharlesBerling',
#  'MaxinePeake',
#  "ArthurO'Connell",
#  'MarkRobson',
#  'MarjattaRaita',
#  'PazdelaHuerta',
#  'ShirleyHenderson',
#  'DenisMénochet',
#  'RobertDowneyJr.',
#  'AldoGiuffrè',
#  'EduardFernández',
#  'EdmundPurdom',
#  'HenrySilva',
#  'PierreArditi',
#  'MichelePlacido',
#  'DianaDors',
#  'SebastianStan',
#  'LewisStone',
#  'SabineAzéma',
#  'StellaStevens',
#  'KariWuhrer',
#  'BillyCrudup',
#  'AndySamberg',
#  'LamSuet',
#  'CharlesHawtrey',
#  'AdamCurtis',
#  "EdO'Neill",
#  'MikiNakatani',
#  'JonLovitz',
#  'NoraDunn',
#  'EddieRedmayne',
#  'TaylorCole',
#  'JeanneCrain',
#  'WongJing',
#  'DickPurcell',
#  'JoanChen',
#  'ChristopherLambert',
#  'WilliamHurt',
#  'StephenMerchant',
#  'JeanRollin',
#  'CatalinaSandinoMoreno',
#  'KellyMcGillis',
#  'VinnieJones',
#  'IanMcNeice',
#  'NigelGreen',
#  'JackKing',
#  'RenOsugi',
#  'PeterCollinson',
#  'EmmanuelleRiva',
#  'EdwardF.Cline',
#  'SybilDanning',
#  'TonyCurran',
#  'JohnAgar',
#  'AnatoliPapanov',
#  'MichelleTrachtenberg',
#  'RandyQuaid',
#  'LisaKudrow',
#  'WilliamBendix',
#  'ShannonTweed',
#  'DavidLowellRich',
#  'WilliamBaldwin',
#  'MonicaBellucci',
#  'BobbyJordan',
#  'ClaireBloom',
#  'ValerioMastandrea',
#  'PeterDinklage',
#  'TommiKorpela',
#  'EliRoth',
#  'PeterCapaldi',
#  'PatrickFugit',
#  'SheaWhigham',
#  'LupeOntiveros',
#  'MichelGalabru',
#  'AnaïsDemoustier',
#  'RayLovelock',
#  'KuFeng',
#  'MarvinJ.Chomsky',
#  'RayWinstone',
#  "IleanaD'Cruz",
#  'WarrenWilliam',
#  'BernieCasey',
#  'BilleAugust',
#  'RobertMiano',
#  'PorterHall',
#  'EvgeniyStychkin',
#  'AnthonyMackie',
#  'PercyHerbert',
#  'Jean-LouisTrintignant',
#  'CarolynJones',
#  'MelvilPoupaud',
#  'IrvingRapper',
#  'GötzGeorge',
#  'CelesteHolm',
#  'LukasHaas',
#  'LeungKar-Yan',
#  'PeterMullan',
#  'FredOlenRay',
#  'SeanConnery',
#  'JayO.Sanders',
#  'SarahPolley',
#  'KimKi-Duk',
#  'KristenWiig',
#  'MikhailUlyanov',
#  'NatPendleton',
#  'Capucine',
#  'KimBodnia',
#  'BobbyCannavale',
#  'DarrenMcGavin',
#  'JackConway',
#  'LiamNeeson',
#  'PierAngeli',
#  'FrankTuttle',
#  'MadelineKahn',
#  'LeslieHoward',
#  'MichaelJeter',
#  'IsabelLucas',
#  'JohnnyLever',
#  'NehemiahPersoff',
#  'EldenHenson',
#  'A.EdwardSutherland',
#  'TessaThompson',
#  'MikeStarr',
#  'JoannaPacula',
#  'ChristopherLee',
#  'PascalGreggory',
#  'MarielHemingway',
#  'BruceBoxleitner',
#  'GunnarBjörnstrand',
#  'RobertDeNiro',
#  'UweBoll',
#  'FredTatasciore',
#  'KristenSchaal',
#  'CaseyKasem',
#  'JoshGad',
#  'RichardBurton',
#  'MadhuriDixit',
#  'JasonLondon',
#  'AlPacino',
#  'CaryElwes',
#  'RobinWilliams',
#  'AlbertoSordi',
#  'ChrisHaywood',
#  'RichardRiehle',
#  'LorenzoLamas',
#  'JoséFerrer',
#  'PeteWalker',
#  'JavierBotet',
#  'AliceCooper',
#  'AnnaLynneMcCord',
#  'ClaudeAutant-Lara',
#  'PhilKarlson',
#  'RichardFarnsworth',
#  'NedBeatty',
#  'JonathanDemme',
#  'GiulianoCarnimeo',
#  'JessicaTandy',
#  'KaneHodder',
#  'CleaDuVall',
#  'DagmarLassander',
#  'FedericoFellini',
#  'MarisaParedes',
#  'DavidOyelowo',
#  'LaraineDay',
#  'PedroAlmodóvar',
#  'GuntherPhilipp',
#  'HelenHunt',
#  'DonRickles',
#  'WilliamPowell',
#  'AdrianPasdar',
#  'DessieFlynn',
#  'RayCollins',
#  'HenryCzerny',
#  'MarlonBrando',
#  'CliftonJames',
#  'MarkDuplass',
#  "ChrisO'Donnell",
#  'JôShishido',
#  'LucaArgentero',
#  'HaroldS.Bucquet',
#  'KenWatanabe',
#  'SilvioOrlando',
#  'LukePerry',
#  'PetePostlethwaite',
#  'JamiGertz',
#  'JeanSmart',
#  'JoeyKing',
#  'RobertCarradine',
#  'GreerGarson',
#  'StephenFrears',
#  'MikeVogel',
#  'AnnMagnuson',
#  'MichaelKeaton',
#  'DavidSoul',
#  'TonyTodd',
#  'ConstanceBennett',
#  'JonHall',
#  'VictorGarber',
#  'BaileeMadison',
#  'LivioLorenzon',
#  'CurtisHanson',
#  'BernardBlier',
#  'RobertRedford',
#  'RichardGrieco',
#  'JasonBateman',
#  'RonnyCox',
#  'VincentSpano',
#  'ElliottNugent',
#  'TheresaRussell',
#  'JohnKrasinski',
#  'NathanLane',
#  'SydneyPollack',
#  'ZacharyScott',
#  'BillyZane',
#  'LouisMandylor',
#  'PupiAvati',
#  'Jean-PaulRouve',
#  'LindsayLohan',
#  'OctaviaSpencer',
#  'JoelGrey',
#  'RayWalston',
#  'SarahHyland',
#  'JohnSavage',
#  'FritzWeaver',
#  'RonaldNeame',
#  'HelenaBonhamCarter',
#  'VirnaLisi',
#  'TonyCox',
#  'ConnieNielsen',
#  'HenryRollins',
#  'AtomEgoyan',
#  'DinoRisi',
#  'LucianoSalce',
#  'JulieAndrews',
#  'KenRussell',
#  'JamesVanDerBeek',
#  'NiaPeeples',
#  'AlastairSim',
#  'RobMorrow',
#  'LadislavSmoljak',
#  'BudCort',
#  'TomBell',
#  'SidseBabettKnudsen',
#  'AdrienBrody',
#  'LoLieh',
#  'LindenAshby',
#  'DaveFranco',
#  'OrlandoBloom',
#  'JayneEastwood',
#  'MikeNewell',
#  'SentaBerger',
#  'CraigR.Baxley',
#  'L.Q.Jones',
#  'MikhailKozakov',
#  'SarahMichelleGellar',
#  'GiorgioFerroni',
#  'LouisKoo',
#  'KasiaSmutniak',
#  'JustinChatwin',
#  'PamelaAdlon',
#  'JoshBrolin',
#  'JonFavreau',
#  'RonOliver',
#  'RobertHutton',
#  'WendiMcLendon-Covey',
#  'MichaelJackson',
#  'KattWilliams',
#  'LewisMilestone',
#  'DonKnotts',
#  'LeeBowman',
#  'CliftonCollinsJr.',
#  'GeorgeMacKay',
#  'NataliaTena',
#  'YvetteMimieux',
#  'CharlesRuggles',
#  'BorisSagal',
#  'CharltonHeston',
#  'JamesBadgeDale',
#  'NickyWhelan',
#  'HenryTravers',
#  'DaveBautista',
#  'AlexCord',
#  'EleanorParker',
#  'BarbaraSukowa',
#  'JenniferConnelly',
#  'DougCampbell',
#  'SimonYam',
#  'VirginiaWeidler',
#  'SergioMartino',
#  'MackSwain',
#  'JohnBoles',
#  'ConstanceCummings',
#  'FredricMarch',
#  'MarkWebber',
#  'JakeGyllenhaal',
#  'AllenCovert',
#  'MauroBolognini',
#  'MenaSuvari',
#  'EvaBirthistle',
#  'GordonHessler',
#  'MarinoGirolami',
#  'ArtCarney',
#  'OssieDavis',
#  'RobertoBenigni',
#  'MasakiSuda',
#  'GeorgeMarshall',
#  'LakeBell',
#  'UweOchsenknecht',
#  'MariusGoring',
#  'AlbertoDeMartino',
#  'OrnellaMuti',
#  'PruittTaylorVince',
#  'RayBaker',
#  'HalNeedham',
#  'RussellPeters',
#  'EugeneLevy',
#  'EduardoNoriega',
#  'LaurenGraham',
#  'RaymondJ.Barry',
#  'KekePalmer',
#  'KeithPoulson',
#  'KarenMok',
#  'CrystalLowe',
#  'AnneConsigny',
#  'HughBonneville',
#  'JulietteLewis',
#  'TiaCarrere',
#  'AliceFaye',
#  'ChrisMarker',
#  'StephenBoyd',
#  'BrittRobertson',
#  'RoshanSeth',
#  'EddyKo',
#  'TonyShalhoub',
#  'FelissaRose',
#  'RobbyBenson',
#  'DianneWiest',
#  'AgostinaBelli',
#  'MichaelRedgrave',
#  'RichardMoll',
#  'LLCoolJ',
#  'GillianJacobs',
#  'AssumptaSerna',
#  'IrenePapas',
#  'RobertWebber',
#  'DonWeis',
#  'AmySedaris',
#  'VirginiaBruce',
#  'SteveGuttenberg',
#  'JohnGlover',
#  'MichaelFeifer',
#  'AndrewLau',
#  'MauraTierney',
#  'ThierryLhermitte',
#  'JaiCourtney',
#  'GeorgeC.Scott',
#  'RamonNovarro',
#  'YvonneMitchell',
#  'TinaLouise',
#  'JackyCheung',
#  'SatyajitRay',
#  'DennisHopper',
#  'JudithGodrèche',
#  'DouglasFairbanksJr.',
#  'ErnieBarbarash',
#  'BrianDonlevy',
#  'CliftonPowell',
#  'EvaMendes',
#  'StuartMargolin',
#  'TyreseGibson',
#  'DreadeMatteo',
#  'LloydKaufman',
#  'WilliamFrawley',
#  'HarryDeanStanton',
#  'GregEvigan',
#  'BrendanFletcher',
#  'RichardGabai',
#  'JonahHill',
#  'MichèleMercier',
#  'OmPuri',
#  'VinceEdwards',
#  'LaetitiaCasta',
#  'RobbieAmell',
#  'TarajiP.Henson',
#  'WarrenBeatty',
#  'SheldonLeonard',
#  'SamuelWest',
#  'LucilleBall',
#  'CharleneChoi',
#  'ArmieHammer',
#  'JohnnyHallyday',
#  'GeorgeMurphy',
#  'JamesCagney',
#  'DavidWayne',
#  'MichelAuclair',
#  'NeilHamilton',
#  'EdLauter',
#  'MimsyFarmer',
#  'AnthonyCaruso',
#  'RenéClément',
#  'DannyLeeSau-Yin',
#  'SeanWhalen',
#  'ChrisSarandon',
#  'MaryMcDonnell',
#  'LeeleeSobieski',
#  'IanMcKellen',
#  'PeterGodfrey',
#  'RobertMorley',
#  'RosamundKwan',
#  ...}

# %%
# Let us see the actors that appears more times in our dataset (that is to say in more movies)
dict_actors_order
# Out:
# {'EricRoberts': 171,
#  'ChristopherLee': 166,
#  'ClarenceNash': 155,
#  'MelBlanc': 144,
#  'DonaldSutherland': 141,
#  'Jr.': 132,
#  'JohnWayne': 127,
#  'GérardDepardieu': 123,
#  'RayMilland': 121,
#  'MichaelIronside': 120,
#  'DannyTrejo': 120,
#  'SamuelL.Jackson': 119,
#  'MichaelMadsen': 118,
#  'MichaelCaine': 114,
#  'JamesMason': 110,
#  'MalcolmMcDowell': 110,
#  'AlbertoSordi': 108,
#  'DonaldPleasence': 107,
#  'LanceHenriksen': 106,
#  'DannyGlover': 102,
#  'RobertDeNiro': 102,
#  'JackieChan': 101,
#  'HarveyKeitel': 101,
#  'WillemDafoe': 101,
#  'ChristopherPlummer': 101,
#  'JohnHurt': 100,
#  'ChristopherWalken': 100,
#  'AnthonyQuinn': 99,
#  'NicolasCage': 99,
#  'JohnCarradine': 99,
#  'SusanSarandon': 99,
#  'MickeyRooney': 98,
#  'DennisHopper': 96,
#  'VincentPrice': 95,
#  'BurtReynolds': 95,
#  'MorganFreeman': 95,
#  'AlecBaldwin': 94,
#  'CatherineDeneuve': 93,
#  'BruceWillis': 92,
#  'LorettaYoung': 91,
#  'JamesCaan': 91,
#  'JohnMalkovich': 90,
#  'MartinSheen': 90,
#  'BruceDern': 90,
#  'LionelBarrymore': 89,
#  'MarcelloMastroianni': 89,
#  'KeithDavid': 89,
#  'RutgerHauer': 88,
#  'StephenMcHattie': 88,
#  'ErnestBorgnine': 88,
#  'DavidCarradine': 86,
#  'RobertDuvall': 86,
#  'HelenMirren': 86,
#  'RobertMitchum': 86,
#  'GeorgeSanders': 85,
#  'JeanRochefort': 85,
#  'LiamNeeson': 85,
#  'MaxvonSydow': 84,
#  'BorisKarloff': 84,
#  'BrianCox': 84,
#  'BetteDavis': 84,
#  'SteveBuscemi': 84,
#  'RonPerlman': 84,
#  'TomSizemore': 83,
#  'JamesFranco': 83,
#  'IsabelleHuppert': 83,
#  'KeenanWynn': 83,
#  'BenKingsley': 83,
#  'WilliamHurt': 82,
#  'KirkDouglas': 82,
#  'VivicaA.Fox': 81,
#  'StanleyTucci': 81,
#  'JamesEarlJones': 81,
#  'BarbaraStanwyck': 80,
#  'BeauBridges': 80,
#  'BillyZane': 80,
#  'HuntzHall': 79,
#  'VirginiaMadsen': 79,
#  'JohnGoodman': 79,
#  'VittorioGassman': 79,
#  'ChristopherLloyd': 79,
#  'AntonioBanderas': 78,
#  'KeanuReeves': 78,
#  'AnthonyHopkins': 78,
#  'ForestWhitaker': 78,
#  'StellanSkarsgård': 78,
#  'RodSteiger': 77,
#  'FrancoNero': 77,
#  'EwanMcGregor': 77,
#  'EdHarris': 77,
#  'JohnLeguizamo': 76,
#  'HenryFonda': 76,
#  'TomHanks': 76,
#  'GlennFord': 76,
#  'TomBerenger': 76,
#  'NickNolte': 76,
#  'DennisQuaid': 75,
#  'PintoColvig': 75,
#  'GeneHackman': 75,
#  'WoodyHarrelson': 75,
#  'NedBeatty': 74,
#  'SamNeill': 74,
#  'RayLiotta': 74,
#  'PeterCushing': 74,
#  'RobertTaylor': 74,
#  'CharlotteRampling': 74,
#  'RoddyMcDowall': 74,
#  'ShelleyWinters': 74,
#  'BruceDavison': 74,
#  'JohnCusack': 74,
#  'CharlesBronson': 73,
#  'RobinWilliams': 73,
#  'CaryGrant': 73,
#  'KlausKinski': 73,
#  'ValKilmer': 73,
#  'VanessaRedgrave': 73,
#  'WilliamH.Macy': 73,
#  'OrsonWelles': 72,
#  'MerylStreep': 72,
#  'KrisKristofferson': 72,
#  'FrankWelker': 72,
#  'JackPalance': 72,
#  'WhoopiGoldberg': 72,
#  'JulianneMoore': 72,
#  'TimRoth': 71,
#  'PeterStormare': 71,
#  'UdoKier': 71,
#  'RobertForster': 71,
#  'JamesStewart': 71,
#  'DanaAndrews': 71,
#  'AlfredMolina': 71,
#  'EllenBurstyn': 71,
#  'LeoGorcey': 71,
#  'CharltonHeston': 70,
#  'MichaelParé': 70,
#  'OliverReed': 70,
#  'RandolphScott': 70,
#  'JeffBridges': 70,
#  'DermotMulroney': 69,
#  'ChristianSlater': 69,
#  'BillPullman': 69,
#  'HerbertLom': 69,
#  'DolphLundgren': 69,
#  'PatrickStewart': 69,
#  'DavidNiven': 68,
#  'LievSchreiber': 68,
#  'DustinHoffman': 68,
#  'AndyLau': 68,
#  'BruceGreenwood': 68,
#  'VingRhames': 68,
#  'ElliottGould': 68,
#  'BrianDennehy': 68,
#  'JohnTravolta': 68,
#  'JimBroadbent': 68,
#  'HarryDeanStanton': 68,
#  'BurtLancaster': 68,
#  'DavidStrathairn': 68,
#  'NicoleKidman': 68,
#  'CameronMitchell': 68,
#  'RosarioDawson': 67,
#  'JohnnyDepp': 67,
#  'EdwardG.Robinson': 67,
#  'JamesRobertsonJustice': 67,
#  'JoanBlondell': 67,
#  'RipTorn': 67,
#  'HumphreyBogart': 67,
#  'JamesCoburn': 67,
#  'TommyLeeJones': 66,
#  'VinnieJones': 66,
#  'AmitabhBachchan': 66,
#  'LaurenceFishburne': 66,
#  'AkshayKumar': 66,
#  'RobertPatrick': 66,
#  'SeanAstin': 66,
#  'PaulSorvino': 66,
#  'GaryOldman': 66,
#  'MichelPiccoli': 66,
#  'RobertDowneyJr.': 66,
#  'SeanBean': 66,
#  'DanAykroyd': 66,
#  'TonyCurtis': 66,
#  'BradDourif': 66,
#  'ClarkGable': 65,
#  'CharlesDurning': 65,
#  'MichaelGambon': 65,
#  'MyrnaLoy': 65,
#  'CaryElwes': 65,
#  'WalterBrennan': 65,
#  'KarenBlack': 65,
#  'UgoTognazzi': 65,
#  'JackBlack': 65,
#  'BusterKeaton': 65,
#  'JohnTurturro': 65,
#  'JohnRhys-Davies': 65,
#  'JoanCrawford': 65,
#  'DeanCain': 65,
#  'AlainDelon': 65,
#  'JeffGoldblum': 65,
#  'StacyKeach': 65,
#  'JohnSaxon': 64,
#  'JohnLithgow': 64,
#  'WilliamHolden': 64,
#  'GaryCooper': 64,
#  'KieferSutherland': 64,
#  'WalterPidgeon': 64,
#  'DannyDeVito': 64,
#  'RichardHarris': 64,
#  'ScottGlenn': 64,
#  'NinoManfredi': 64,
#  'BillPaxton': 64,
#  'GabrielByrne': 64,
#  'RobertRyan': 63,
#  'PaulNewman': 63,
#  'EthanHawke': 63,
#  'JohnCleese': 63,
#  'RichardDreyfuss': 63,
#  'JohnSavage': 63,
#  'JosephCotten': 63,
#  'JamesWoods': 63,
#  'KathyBates': 63,
#  'VanJohnson': 63,
#  'JackLemmon': 63,
#  'BingCrosby': 63,
#  'RichardGere': 62,
#  'SeymourCassel': 62,
#  'JamesGarner': 62,
#  'WilliamForsythe': 62,
#  'MatthewLillard': 62,
#  'ClaudiaCardinale': 62,
#  'JonVoight': 62,
#  'JeffFahey': 62,
#  "VincentD'Onofrio": 62,
#  'OliverPlatt': 62,
#  'KevinBacon': 62,
#  'PaoloVillaggio': 62,
#  'DarylHannah': 62,
#  'EliWallach': 62,
#  'KurtRussell': 62,
#  'CateBlanchett': 62,
#  'BobHoskins': 62,
#  'HelenaBonhamCarter': 62,
#  'HeatherGraham': 62,
#  'PeterCoyote': 62,
#  'SophiaLoren': 61,
#  'WillFerrell': 61,
#  'LewisStone': 61,
#  'TrevorHoward': 61,
#  'GlennClose': 61,
#  'NaomiWatts': 61,
#  'SamRockwell': 61,
#  'JoelMcCrea': 61,
#  'GaryBusey': 61,
#  'ClintEastwood': 61,
#  'DavidKoechner': 61,
#  'JohnIreland': 61,
#  'SeanConnery': 61,
#  'JeanReno': 61,
#  'C.ThomasHowell': 61,
#  'GiancarloGiannini': 61,
#  'GuyPearce': 61,
#  'MickeyRourke': 61,
#  'TonyTodd': 61,
#  'TomWilkinson': 61,
#  'RaymondBurr': 61,
#  'TreatWilliams': 60,
#  'MattDamon': 60,
#  'DeanStockwell': 60,
#  'BelaLugosi': 60,
#  'CiaránHinds': 60,
#  'SigourneyWeaver': 60,
#  'JeffDaniels': 60,
#  'ColinFirth': 60,
#  'DavidArquette': 60,
#  'RichardWidmark': 60,
#  'MirandaRichardson': 60,
#  'ArmandAssante': 60,
#  'MatthewModine': 60,
#  'BudSpencer': 60,
#  'FayeDunaway': 59,
#  'WalterMatthau': 59,
#  'MartinLandau': 59,
#  'RobertLoggia': 59,
#  'JaneWyman': 59,
#  'JohnC.Reilly': 59,
#  'J.K.Simmons': 59,
#  'IanHolm': 59,
#  'GeraldineChaplin': 59,
#  'GingerRogers': 59,
#  'AlanArkin': 59,
#  'SammoHung': 59,
#  'ShirleyMacLaine': 59,
#  'BurtYoung': 59,
#  'SeanPatrickFlanery': 58,
#  'JamesCagney': 58,
#  'RandyQuaid': 58,
#  'ClorisLeachman': 58,
#  'BasilRathbone': 58,
#  'DianeLane': 58,
#  'PierceBrosnan': 58,
#  'JohnHeard': 58,
#  'CliveOwen': 58,
#  'FredMacMurray': 58,
#  'RalphFiennes': 58,
#  'JulietteBinoche': 58,
#  'CasperVanDien': 58,
#  'JudiDench': 58,
#  'SharonStone': 58,
#  'MarySteenburgen': 58,
#  'RobertWagner': 58,
#  'HenrySilva': 58,
#  'MimiRogers': 58,
#  'AlPacino': 57,
#  'DanielAuteuil': 57,
#  'RobertYoung': 57,
#  'BenStiller': 57,
#  'ToniCollette': 57,
#  'TimothySpall': 57,
#  'JohnMills': 57,
#  'KevinSpacey': 57,
#  'BillMurray': 57,
#  'CorbinBernsen': 57,
#  'RosannaArquette': 57,
#  'DonnieYen': 57,
#  'EddieAlbert': 57,
#  'SylvesterStallone': 57,
#  'PatriciaClarkson': 57,
#  'JasonRobards': 57,
#  'WilliamShatner': 57,
#  'SpencerTracy': 57,
#  'LinShaye': 57,
#  'CesarRomero': 57,
#  'JoePantoliano': 56,
#  'JackNicholson': 56,
#  'MichaelBiehn': 56,
#  'JulietteLewis': 56,
#  'OliverHardy': 56,
#  'LukeWilson': 56,
#  'WillPatton': 56,
#  'JacquelineBisset': 56,
#  'MathieuAmalric': 56,
#  'PaulRudd': 56,
#  'BradPitt': 56,
#  "EdmondO'Brien": 56,
#  'ChrisCooper': 56,
#  'AidanQuinn': 56,
#  'TomSkerritt': 56,
#  'PaulGiamatti': 56,
#  'PeterSellers': 56,
#  'GeneLockhart': 56,
#  'JaneFonda': 56,
#  'BillNighy': 56,
#  'EmmaThompson': 56,
#  'HarrisonFord': 56,
#  'LeeVanCleef': 56,
#  'JamesCromwell': 56,
#  'TildaSwinton': 56,
#  'PrakashRaj': 56,
#  'KeithCarradine': 56,
#  'SamElliott': 56,
#  'OwenWilson': 56,
#  'RobertRedford': 56,
#  'KevinSorbo': 56,
#  'DavidCross': 55,
#  'CatherineKeener': 55,
#  'BurgessMeredith': 55,
#  'JenniferJasonLeigh': 55,
#  'CubaGoodingJr.': 55,
#  'ElijahWood': 55,
#  "PeterO'Toole": 55,
#  'FernandoRey': 55,
#  'ErnieHudson': 55,
#  'WilliamPowell': 55,
#  'KristinScottThomas': 55,
#  'ArthurKennedy': 55,
#  'LeeJ.Cobb': 55,
#  'MelGibson': 55,
#  'DonaldCrisp': 55,
#  'JonathanPryce': 55,
#  'TomArnold': 55,
#  'LaurenceOlivier': 55,
#  'GeorgeKennedy': 55,
#  'PhilippeNoiret': 55,
#  'PhilipSeymourHoffman': 55,
#  'FrankLangella': 54,
#  'JoeMantegna': 54,
#  'FredWilliamson': 54,
#  'SterlingHolloway': 54,
#  'StevenSeagal': 54,
#  'JackWarden': 54,
#  'RockHudson': 54,
#  'LouisKoo': 54,
#  'MarkHamill': 54,
#  'BillyBletcher': 54,
#  'FrankMorgan': 54,
#  'JuddNelson': 54,
#  'PeterFonda': 54,
#  'BarbaraHershey': 54,
#  'OlivierGourmet': 54,
#  'StephenLang': 54,
#  'DenholmElliott': 54,
#  'JohnHawkes': 54,
#  'JeremyIrons': 53,
#  'Jean-ClaudeVanDamme': 53,
#  'EdwardArnold': 53,
#  'AnjelicaHuston': 53,
#  'FrancoFranchi': 53,
#  'KevinCostner': 53,
#  'BillyBobThornton': 53,
#  'GregoryPeck': 53,
#  'JoanCollins': 53,
#  'StephenDorff': 53,
#  'VincentPastore': 53,
#  'VictorMature': 53,
#  'WardBond': 53,
#  'RichardRiehle': 53,
#  'Jean-PaulBelmondo': 53,
#  'DrewBarrymore': 53,
#  'DenzelWashington': 53,
#  'TadanobuAsano': 53,
#  'PenélopeCruz': 53,
#  'SteveCoogan': 53,
#  'RobertEnglund': 53,
#  'GinaGershon': 53,
#  'ChristinaRicci': 53,
#  'LeslieNielsen': 53,
#  'DianeKeaton': 52,
#  'RichardBurton': 52,
#  'MichaelYork': 52,
#  'KevinCorrigan': 52,
#  'MattDillon': 52,
#  'ThomasKretschmann': 52,
#  'StephenBaldwin': 52,
#  'MatthewBroderick': 52,
#  'JoshBrolin': 52,
#  'M.EmmetWalsh': 52,
#  'DavidWarner': 52,
#  'KirstenDunst': 52,
#  'ArnoldSchwarzenegger': 52,
#  'MarisaTomei': 52,
#  'JudeLaw': 52,
#  'MarciaGayHarden': 52,
#  'BrendanGleeson': 52,
#  'AllenJenkins': 52,
#  'KevinPollak': 52,
#  'AnupamKher': 52,
#  'JohnDiehl': 51,
#  'IanMcShane': 51,
#  'Totò': 51,
#  'ErrolFlynn': 51,
#  'WilliamBendix': 51,
#  'JaneaneGarofalo': 51,
#  'LaceyChabert': 51,
#  'XanderBerkeley': 51,
#  'EliasKoteas': 51,
#  'StephenFry': 51,
#  'PeterLorre': 51,
#  'MaggieSmith': 51,
#  'JulianSands': 51,
#  'StanLaurel': 51,
#  'CharlesChaplin': 51,
#  'SimonYam': 51,
#  'SalmanKhan': 51,
#  'LochlynMunro': 51,
#  'JasonIsaacs': 51,
#  'DavidThewlis': 51,
#  'SamShepard': 51,
#  'JamesLeGros': 51,
#  'RodTaylor': 51,
#  'CharlieSheen': 51,
#  'ChristopherMcDonald': 51,
#  'JenniferTilly': 51,
#  'ReginaldOwen': 51,
#  'WoodyAllen': 51,
#  'HarryAndrews': 51,
#  'BartonMacLane': 51,
#  'TimothyHutton': 51,
#  'CiccioIngrassia': 50,
#  'TaraStrong': 50,
#  'ClaudeRains': 50,
#  'UmaThurman': 50,
#  'DirkBogarde': 50,
#  'PeterFalk': 50,
#  'AkimTamiroff': 50,
#  'ChevyChase': 50,
#  'MarkStrong': 50,
#  'MichaelDouglas': 50,
#  'RenatoPozzetto': 50,
#  'RobertMontgomery': 50,
#  'JerryLewis': 50,
#  'StephenRea': 50,
#  'MarioAdorf': 50,
#  'AngelaLansbury': 50,
#  'Jean-LouisTrintignant': 50,
#  'KaneHodder': 50,
#  'WilliamSadler': 50,
#  'LouDiamondPhillips': 50,
#  'LauraDern': 50,
#  'AllisonJanney': 50,
#  "MaureenO'Hara": 50,
#  'GeorgeBrent': 50,
#  'ElizabethTaylor': 50,
#  'KevinKline': 50,
#  'DennisPrice': 50,
#  'ColmFeore': 50,
#  'MiraSorvino': 50,
#  'CharlesBoyer': 50,
#  'AnthonyLaPaglia': 50,
#  'PareshRawal': 50,
#  'DeanMartin': 50,
#  'RalphBellamy': 49,
#  'WarrenWilliam': 49,
#  'FredricMarch': 49,
#  'LambertWilson': 49,
#  'SylvaKoscina': 49,
#  'RobLowe': 49,
#  'StephenChow': 49,
#  'AdamSandler': 49,
#  'MelvynDouglas': 49,
#  'AlanHale': 49,
#  'JeanneMoreau': 49,
#  'OmPuri': 49,
#  'ParkerPosey': 49,
#  'WallaceShawn': 49,
#  'RyanReynolds': 49,
#  'TimCurry': 49,
#  'KatyJurado': 49,
#  'SterlingHayden': 49,
#  'TerenceStamp': 49,
#  'MichaelKeaton': 49,
#  'JustinLong': 49,
#  'GeorgeSegal': 49,
#  'MelissaLeo': 49,
#  'MatthewMcConaughey': 49,
#  'FranciscoRabal': 49,
#  'ChristopherLambert': 49,
#  'NaseeruddinShah': 49,
#  'JamesRemar': 49,
#  'ClaudetteColbert': 49,
#  'LouiseFletcher': 49,
#  'AdrienBrody': 48,
#  'RobertMorley': 48,
#  'NataliePortman': 48,
#  'RayWise': 48,
#  'AlanBates': 48,
#  'DickPowell': 48,
#  'PeterUstinov': 48,
#  'JoanCusack': 48,
#  'RachaelLeighCook': 48,
#  'FrankSinatra': 48,
#  'AlecGuinness': 48,
#  'BrianKeith': 48,
#  'JeanSimmons': 48,
#  'SalmaHayek': 48,
#  'JuliaRoberts': 48,
#  'AdolfoCeli': 48,
#  'GuyKibbee': 48,
#  'AndréDussollier': 48,
#  'AllySheedy': 48,
#  'HugoWeaving': 48,
#  'SeanPenn': 48,
#  'AdolpheMenjou': 48,
#  'JeanGabin': 48,
#  'TimRobbins': 48,
#  'TilSchweiger': 47,
#  'JoshLucas': 47,
#  'EdBegleyJr.': 47,
#  'BlytheDanner': 47,
#  'VinceVaughn': 47,
#  'JetLi': 47,
#  'LuisGuzmán': 47,
#  'J.CarrolNaish': 47,
#  'JohnGielgud': 47,
#  'LiliTaylor': 47,
#  'SeanYoung': 47,
#  'SidneyPoitier': 47,
#  'RobertVaughn': 47,
#  'PamGrier': 47,
#  'ElizabethBanks': 47,
#  'AgnesMoorehead': 47,
#  'MichellePfeiffer': 47,
#  'JamesMarsden': 47,
#  'WinonaRyder': 47,
#  'WalterHuston': 47,
#  'ChowYun-Fat': 47,
#  'JanetLeigh': 47,
#  'WaltDisney': 47,
#  'IsabellaRossellini': 47,
#  'KimCoates': 47,
#  'JudyGreer': 47,
#  'KristenWiig': 47,
#  'JasonLondon': 47,
#  'IanMcKellen': 47,
#  'MaryAstor': 47,
#  'LouisdeFunès': 47,
#  'RichardJenkins': 47,
#  'MartinBalsam': 47,
#  'MarkWahlberg': 47,
#  'RichardCrenna': 47,
#  'LauraLinney': 46,
#  'OrnellaMuti': 46,
#  'CarolKane': 46,
#  'WesleySnipes': 46,
#  'BruceMcGill': 46,
#  'BenGazzara': 46,
#  'TerenceHill': 46,
#  'JeffreyTambor': 46,
#  'EddieMurphy': 46,
#  'WilliamDemarest': 46,
#  'CedricHardwicke': 46,
#  'PriyankaChopra': 46,
#  'GregKinnear': 46,
#  'CharlizeTheron': 46,
#  'BarrySullivan': 46,
#  'MarlonBrando': 46,
#  'AnneHeche': 46,
#  'MariaBello': 46,
#  'KatharineHepburn': 46,
#  'JeffreyCombs': 46,
#  'BarbaraHale': 46,
#  'BobbyCannavale': 46,
#  'CheechMarin': 46,
#  'BenAffleck': 46,
#  'TimBlakeNelson': 46,
#  'LukasHaas': 46,
#  'BernardBlier': 46,
#  'MarionCotillard': 46,
#  'RobertStack': 46,
#  'CliffRobertson': 46,
#  'JonGries': 46,
#  'RichardConte': 46,
#  'MichaelShannon': 46,
#  'PeterBoyle': 46,
#  'SteveMartin': 46,
#  'AsiaArgento': 46,
#  'GiancarloEsposito': 46,
#  'BernardLee': 46,
#  'GilBellows': 46,
#  'ClancyBrown': 46,
#  'AndyGarcia': 46,
#  'Ice-T': 45,
#  'AnthonyPerkins': 45,
#  'ChristianBale': 45,
#  'AnneBancroft': 45,
#  'CharlesDance': 45,
#  'PeterLawford': 45,
#  'JohnLitel': 45,
#  'KateWinslet': 45,
#  'FamkeJanssen': 45,
#  'JeremySisto': 45,
#  'MoritzBleibtreu': 45,
#  'AndieMacDowell': 45,
#  'M.C.Gainey': 45,
#  'RayWinstone': 45,
#  'LloydBridges': 45,
#  'SissySpacek': 45,
#  'JamesGleason': 45,
#  'TyronePower': 45,
#  'JasonFlemyng': 45,
#  'GeorgeC.Scott': 45,
#  'SusanHayward': 45,
#  'GianMariaVolonté': 45,
#  "PatO'Brien": 45,
#  'JamieLeeCurtis': 45,
#  'CarlaGugino': 45,
#  'FranchotTone': 45,
#  'LucilleBall': 45,
#  'LeeMarvin': 45,
#  'BobHope': 45,
#  'RobSchneider': 45,
#  'AngelinaJolie': 45,
#  'RichardAttenborough': 45,
#  'LouisGossettJr.': 45,
#  'VincentCassel': 45,
#  'HelenHunt': 44,
#  'RobertCarradine': 44,
#  'FredWard': 44,
#  'EricStoltz': 44,
#  'LonChaneyJr.': 44,
#  'AlanRickman': 44,
#  'CharlotteGainsbourg': 44,
#  'DemiMoore': 44,
#  'LaurenBacall': 44,
#  'RachelWeisz': 44,
#  'RichardE.Grant': 44,
#  'JohnSchneider': 44,
#  'EugenePallette': 44,
#  'BrianDonlevy': 44,
#  'JimCarrey': 44,
#  'AlanCumming': 44,
#  'TomCruise': 44,
#  'DannyAiello': 44,
#  'IngridBergman': 44,
#  'RoyScheider': 44,
#  'CharlesCoburn': 44,
#  'JossAckland': 44,
#  'AlanLadd': 44,
#  'GeorgesMéliès': 44,
#  'ThomasJane': 44,
#  'RoseByrne': 44,
#  'MelanieGriffith': 44,
#  'MiaFarrow': 44,
#  'LinoVentura': 44,
#  'ThierryLhermitte': 44,
#  'JamieFoxx': 44,
#  'FredAstaire': 44,
#  'EdwardEverettHorton': 44,
#  'JimCummings': 44,
#  'BroderickCrawford': 44,
#  'DiegoAbatantuono': 44,
#  'GeorgeClooney': 44,
#  'YvonneDeCarlo': 44,
#  'DonCheadle': 44,
#  'KappeiYamaguchi': 44,
#  'EllenBarkin': 44,
#  'DwayneJohnson': 44,
#  'ViggoMortensen': 44,
#  'ColmMeaney': 44,
#  "BeverlyD'Angelo": 44,
#  'MarkRuffalo': 44,
#  'ColinFarrell': 44,
#  'StephenTobolowsky': 44,
#  'KevinHart': 43,
#  'C.AubreySmith': 43,
#  'KarlMalden': 43,
#  'JamesBelushi': 43,
#  'CurdJürgens': 43,
#  'DavidKeith': 43,
#  'JenaMalone': 43,
#  'HalHolbrook': 43,
#  'NastassjaKinski': 43,
#  'RogerMoore': 43,
#  'AndyDevine': 43,
#  'ClintHoward': 43,
#  'LloydNolan': 43,
#  'EdwardHerrmann': 43,
#  'AndyDick': 43,
#  'OliviadeHavilland': 43,
#  'Ann-Margret': 43,
#  'RobbieColtrane': 43,
#  'VanHeflin': 43,
#  'GilbertRoland': 43,
#  'ReeseWitherspoon': 43,
#  'TimThomerson': 43,
#  'OmarSharif': 43,
#  'LukeGoss': 43,
#  'LaurenHolly': 43,
#  'RomainDuris': 43,
#  'JeffBennett': 43,
#  'GerardButler': 43,
#  'MichaelSheen': 43,
#  'KimBasinger': 43,
#  'WallaceBeery': 43,
#  'ThomasMitchell': 43,
#  'GiulianoGemma': 43,
#  'ValeriaGolino': 43,
#  'HughJackman': 42,
#  'LionelStander': 42,
#  'PatrickWarburton': 42,
#  'BillMoseley': 42,
#  'UnaMerkel': 42,
#  'CameronDiaz': 42,
#  'CraigSheffer': 42,
#  'MichaelNyqvist': 42,
#  'SethRogen': 42,
#  'BrendanFraser': 42,
#  'JasonBateman': 42,
#  'CharlesLaughton': 42,
#  'SteveZahn': 42,
#  'PatriciaArquette': 42,
#  'VittorioDeSica': 42,
#  'Jean-ClaudeBrialy': 42,
#  'EmilyWatson': 42,
#  'TerrenceHoward': 42,
#  'SimonPegg': 42,
#  'KayFrancis': 42,
#  'DabneyColeman': 42,
#  'TeriGarr': 42,
#  'BenedictCumberbatch': 42,
#  'DebbieReynolds': 42,
#  'ColleenCamp': 42,
#  'AldoRay': 42,
#  'JamesBrolin': 42,
#  'LionelAtwill': 42,
#  'GreyDeLisle': 42,
#  'GiovanniRibisi': 42,
#  'KevinSmith': 42,
#  'GrahamGreene': 42,
#  'CliftonCollinsJr.': 42,
#  'TellySavalas': 42,
#  'RhysIfans': 41,
#  'BrionJames': 41,
#  'PattonOswalt': 41,
#  'BruceCampbell': 41,
#  'DavidMorse': 41,
#  'EdwardFurlong': 41,
#  'GlendaFarrell': 41,
#  'ChrisRock': 41,
#  'SteveCarell': 41,
#  'DominiqueSwain': 41,
#  'HerbertMarshall': 41,
#  'MichaelMurphy': 41,
#  'TerryCrews': 41,
#  'MichaelHordern': 41,
#  'MonicaBellucci': 41,
#  'JoséFerrer': 41,
#  'JodieFoster': 41,
#  'MollyParker': 41,
#  'MichaelRapaport': 41,
#  'RichardRoundtree': 41,
#  'AnneHathaway': 41,
#  'SandraBullock': 41,
#  'AlfreWoodard': 41,
#  'LoLieh': 41,
#  'JenniferConnelly': 41,
#  'JamieKennedy': 41,
#  'DanielBrühl': 41,
#  'PeterGallagher': 41,
#  'MichaelJaiWhite': 41,
#  'StuartWhitman': 41,
#  'AnnSheridan': 41,
#  'CrispinGlover': 41,
#  'RussellCrowe': 41,
#  'BenJohnson': 41,
#  'AndrewMcCarthy': 41,
#  'DeeWallace': 41,
#  'AmySmart': 41,
#  'LyleTalbot': 41,
#  'JasonStatham': 41,
#  'EricTsang': 41,
#  'LenaHeadey': 40,
#  'MichaelMcKean': 40,
#  'EleanorParker': 40,
#  'AnnabellaSciorra': 40,
#  'LewAyres': 40,
#  'JosephGordon-Levitt': 40,
#  'BrittanyMurphy': 40,
#  'StephenRoot': 40,
#  'PenelopeAnnMiller': 40,
#  'HardyKrüger': 40,
#  'HarryMorgan': 40,
#  'ClaireTrevor': 40,
#  'PeterSarsgaard': 40,
#  'JamesWhitmore': 40,
#  'DenisLeary': 40,
#  'KeiraKnightley': 40,
#  'AngieDickinson': 40,
#  'DonAmeche': 40,
#  'GordonMitchell': 40,
#  'JeffreyWright': 40,
#  'MichaelRedgrave': 40,
#  'LinoBanfi': 40,
#  'LanaTurner': 40,
#  'ChrisMulkey': 40,
#  'NeveCampbell': 40,
#  'AnilKapoor': 40,
#  'PhilipBakerHall': 40,
#  'EmilyBlunt': 40,
#  'ScarlettJohansson': 40,
#  'MichelleYeoh': 40,
#  'ShintarôKatsu': 40,
#  'TobyJones': 40,
#  'ChloëSevigny': 40,
#  'NatashaLyonne': 40,
#  'DeanJagger': 40,
#  'AnneBaxter': 40,
#  'VirginiaMayo': 40,
#  'AngelaBassett': 40,
#  'MichelePlacido': 40,
#  'CyrilCusack': 40,
#  'RichardJaeckel': 40,
#  'HarryCarey': 40,
#  'JasonMewes': 39,
#  'JohnathonSchaech': 39,
#  'RobertDavi': 39,
#  'GwynethPaltrow': 39,
#  'ShirleyTemple': 39,
#  'RobertCarlyle': 39,
#  'WilliamFichtner': 39,
#  'GabrieleFerzetti': 39,
#  'MaggieCheung': 39,
#  'EmilyMortimer': 39,
#  'CoreyFeldman': 39,
#  'StockardChanning': 39,
#  'DavidBradley': 39,
#  'DerekJacobi': 39,
#  'Vesa-MattiLoiri': 39,
#  'RufusSewell': 39,
#  'GenaRowlands': 39,
#  'HarryDavenport': 39,
#  'StevenBauer': 39,
#  'BryanBrown': 39,
#  'SethGreen': 39,
#  'MichelSerrault': 39,
#  'JamesSpader': 39,
#  'KennethBranagh': 39,
#  'BarryCorbin': 39,
#  'JenniferAniston': 39,
#  'BenoîtPoelvoorde': 39,
#  'JessicaLange': 39,
#  'AvaGardner': 39,
#  'DorisDay': 39,
#  'LeaThompson': 39,
#  'AnnetteBening': 39,
#  'KristySwanson': 39,
#  'NathalieBaye': 39,
#  'StefaniaSandrelli': 39,
#  'FrankMcHugh': 39,
#  'DannyHuston': 39,
#  'ChazzPalminteri': 39,
#  'MarkBooneJunior': 39,
#  'TomSelleck': 39,
#  'F.MurrayAbraham': 39,
#  'LucyLiu': 39,
#  'JürgenProchnow': 39,
#  'LouCostello': 39,
#  'JohnRatzenberger': 39,
#  'EnricoMontesano': 39,
#  'BillHader': 39,
#  'JamesHong': 39,
#  'CampbellScott': 39,
#  'SteveGuttenberg': 38,
#  'RupertEverett': 38,
#  'JesseEisenberg': 38,
#  'MartinFreeman': 38,
#  'VincentLindon': 38,
#  'MillaJovovich': 38,
#  'RichardHarrison': 38,
#  'DanielleDarrieux': 38,
#  'MenaSuvari': 38,
#  'AoiMiyazaki': 38,
#  'BokeemWoodbine': 38,
#  'StewartGranger': 38,
#  'HumeCronyn': 38,
#  'BradleyCooper': 38,
#  'JoaquinPhoenix': 38,
#  'JonahHill': 38,
#  'DianeKruger': 38,
#  'Jean-PierreDarroussin': 38,
#  'HughGrant': 38,
#  'AshleyJudd': 38,
#  'EmmanuelleSeigner': 38,
#  'DeborahKerr': 38,
#  'QueenLatifah': 38,
#  'RonaldReagan': 38,
#  'AnnieGirardot': 38,
#  'JoaquimdeAlmeida': 38,
#  'JackHawkins': 38,
#  'WilfridHyde-White': 38,
#  'AlexandraPaul': 38,
#  'EdwigeFenech': 38,
#  'ChloëGraceMoretz': 38,
#  'GretaScacchi': 38,
#  'MichaelLerner': 38,
#  'JudgeReinhold': 38,
#  'SarahJessicaParker': 38,
#  'IanHart': 38,
#  'MischaBarton': 38,
#  'RonLivingston': 38,
#  'RalphRichardson': 38,
#  'JulieWalters': 38,
#  'JamesFox': 38,
#  'DakotaFanning': 38,
#  'VictorJory': 38,
#  'WilliamR.Moses': 38,
#  'GeoffreyRush': 38,
#  'KyraSedgwick': 38,
#  'MichaelRooker': 38,
#  'DouglasFairbanksJr.': 38,
#  'AlanAlda': 38,
#  'HalleBerry': 38,
#  'DavidOgdenStiers': 38,
#  'RoryCalhoun': 38,
#  'WernerHerzog': 38,
#  'FredWillard': 38,
#  'HenryThomas': 38,
#  'EugeneLevy': 38,
#  'EdLauter': 38,
#  'IdrisElba': 38,
#  'SherilynFenn': 38,
#  'JaneLynch': 38,
#  'KristenStewart': 38,
#  "CatherineO'Hara": 38,
#  'RichardCarlson': 38,
#  "MaureenO'Sullivan": 38,
#  'WarrenOates': 38,
#  'RadhaMitchell': 37,
#  'JaneSeymour': 37,
#  'EddieIzzard': 37,
#  'StéphaneAudran': 37,
#  'DanHedaya': 37,
#  'DennisHaysbert': 37,
#  'SallyField': 37,
#  'BillyCrudup': 37,
#  'Mary-LouiseParker': 37,
#  'JoanBennett': 37,
#  'JamesMacDonald': 37,
#  'LonChaney': 37,
#  'AdamBaldwin': 37,
#  'WendyCrewson': 37,
#  'ElisabethShue': 37,
#  ...}

# %% [markdown]
# Something really interesting, worth analysing more in depth is that even though Eric Roberts appears in more movies than **Susan Sarandon**, Sarandon has a higher eigenvector centrality. So the contacts of Susan has more contacts themselves, giving Sarandon a richer network.

# %%
# the lowest connected actor/director
dict(sorted(eigenvector_centrality.items(), key=lambda item: item[1],reverse=False))
# Out:
# {'LotteReiniger': 3.584946815473141e-46,
#  'JamesH.White': 3.584946815473141e-46,
#  'ChristianGonzález': 3.584946815473141e-46,
#  'AlexandrePromio': 3.584946815473141e-46,
#  'FrederickWiseman': 3.584946815473141e-46,
#  'DzigaVertov': 3.584946815473141e-46,
#  'LavDiaz': 3.584946815473141e-46,
#  'KemalSunal': 3.584946815473141e-46,
#  'TakashiIto': 3.759089191981565e-40,
#  'LouisTheroux': 3.759089191981565e-40,
#  'StanBrakhage': 3.759089191981565e-40,
#  'NormanMcLaren': 3.759089191981565e-40,
#  'WilliamK.L.Dickson': 3.759089191981565e-40,
#  'SegundodeChomón': 3.759089191981565e-40,
#  'GeorgesMéliès': 3.759089191981565e-40,
#  'TakahiroSakurai': 1.3763183504389725e-09,
#  'MaayaSakamoto': 6.922400908369351e-09,
#  'TomokazuSeki': 1.9169493036493868e-08,
#  'AjuVarghese': 5.145900780813246e-08,
#  'LeonidGayday': 1.6247957402675293e-07,
#  'ZdeněkSvěrák': 1.828419874820206e-07,
#  'LadislavSmoljak': 1.8403651552157137e-07,
#  'YuichiNakamura': 1.8474993096824648e-07,
#  'KlaraRumyanova': 2.2071452276525148e-07,
#  'VasiliyLivanov': 2.298045143462296e-07,
#  'SimoSalminen': 2.344116599553227e-07,
#  'MarjattaRaita': 2.3594188126522643e-07,
#  'SpedePasanen': 2.3594188126522643e-07,
#  'KenjiMisumi': 2.590678594699575e-07,
#  'MariyaVinogradova': 3.9149191812565563e-07,
#  'NivinPauly': 4.506258677107831e-07,
#  'KunihikoYuyama': 4.739418795283594e-07,
#  'KimSang-ho': 5.173137953646905e-07,
#  'EreKokkonen': 5.88751356598789e-07,
#  'KiraMuratova': 8.02504160383159e-07,
#  'JeanRollin': 8.369316896616745e-07,
#  'Jean-MarieStraub': 8.424359817576602e-07,
#  'MikhailBoyarskiy': 8.713481689075288e-07,
#  'KouichiYamadera': 1.0590659980241992e-06,
#  'FahadhFaasil': 1.3154051163584534e-06,
#  'WakanaYamazaki': 1.3464438627529005e-06,
#  'MasakiSuda': 1.3857182632840084e-06,
#  'PrithvirajSukumaran': 1.4103272130968337e-06,
#  'JangYoung-nam': 1.5032237874082185e-06,
#  'Jyothika': 1.6352025679394929e-06,
#  'NedumudiVenu': 1.6455527045686235e-06,
#  'BernardGiraudeau': 0.0006353373571646781,
#  'LeeByung-hun': 0.0006353517694542338,
#  'J.FarrellMacDonald': 0.0006366175721760029,
#  'RochelleHudson': 0.0006383082040311485,
#  'BuntaSugawara': 0.000638336330021878,
#  'LeslieGoodwins': 0.0006391576512811156,
#  'TonyLeungKaFai': 0.0006392529731590864,
#  'LeïlaBekhti': 0.0006399329016316627,
#  'HenriVerneuil': 0.000642681346718769,
#  'TomorowoTaguchi': 0.000643145541297246,
#  'AllanEdwall': 0.000644034127459875,
#  'JuanDiego': 0.0006453492052151447,
#  'KatjaRiemann': 0.000648544987831655,
#  'MaxOphüls': 0.0006496479423764115,
#  'ÀlexBrendemühl': 0.0006507199644940386,
#  'CeciliaRoth': 0.0006518316137375594,
#  'ImanolArias': 0.0006529051368207905,
#  'NikitaMikhalkov': 0.0006544423716705316,
#  'KellySheridan': 0.0006552396685937142,
#  'JayChapman': 0.0006583456467872371,
#  'MarkDamon': 0.0006625445212482559,
#  'KojiYakusho': 0.0006634442100017279,
#  'EmmanuelleRiva': 0.0006672734965690337,
#  'GianniGarko': 0.0006694346385055301,
#  'RosalbaNeri': 0.0006696417650299222,
#  'CharlesVanel': 0.0006719975681587009,
#  'AlexDescas': 0.0006745991969413549,
#  'KarlheinzBöhm': 0.000674669719408594,
#  'RobertoRossellini': 0.0006797967428482297,
#  'ClaudeDauphin': 0.0006830263690174289,
#  'CeciliaParker': 0.0006948166244026483,
#  'Miou-Miou': 0.0006951862429496122,
#  'BrinkeStevens': 0.0006960174428662172,
#  'PennySingleton': 0.0006962537990031131,
#  'CristianaCapotondi': 0.000696427034277648,
#  'RayLovelock': 0.0006970599114509226,
#  'RosamundKwan': 0.0007049238839212137,
#  'VictorSenYung': 0.0007061735555743437,
#  'ClovisCornillac': 0.0007069726228002374,
#  'MarisaMerlini': 0.0007073887734137116,
#  'FrancoProsperi': 0.0007093593516256905,
#  'Cantinflas': 0.0007100815867431529,
#  'AnneGwynne': 0.0007117742574044903,
#  'FrançoisPérier': 0.0007120389957463016,
#  'JeanYarbrough': 0.0007120450204328733,
#  'AntonioSabato': 0.0007132263105836728,
#  'MichèleMorgan': 0.0007143900098341531,
#  'MarkJean': 0.0007149955800558374,
#  'LucMerenda': 0.0007159893342041258,
#  'KonstantinKhabenskiy': 0.0007169227468308002,
#  'ErichvonStroheim': 0.0007176191856943367,
#  'JohnBoles': 0.000718075267301801,
#  'MarioCarotenuto': 0.0007186489597978393,
#  'JayKaras': 0.0007205571541454386,
#  'WilliamHanna': 0.0007223181316897929,
#  'AntonioResines': 0.0007223246552254487,
#  'MarieDressler': 0.0007223293218912466,
#  'AntoniodelaTorre': 0.0007228122512853363,
#  'KinjiFukasaku': 0.000724699574666048,
#  'CliveBrook': 0.0007262669596917656,
#  'AlAdamson': 0.000727658730677212,
#  'DeepikaPadukone': 0.0007281777842500286,
#  'CollinChou': 0.0007292891222655222,
#  'GeorgeHilton': 0.0007293132379991208,
#  'CatherineFrot': 0.0007296251237497619,
#  'Totò': 0.0010496686764581513,
#  'WilliamBeaudine': 0.0010517756559841134,
#  'AdrianoCelentano': 0.0010578275857206448,
#  'JeromeCowan': 0.001058420435705963,
#  'PhyllisCalvert': 0.0010588279021884655,
#  'ReginaldLeBorg': 0.0010605587023247791,
#  'ClaudeRich': 0.0010614347047658561,
#  'KayWalsh': 0.0010617662748914083,
#  'AlfredL.Werker': 0.0010659572170635338,
#  'NanniLoy': 0.0010667994896546337,
#  'MaryBethHughes': 0.0010680656526170773,
#  'SaraCanning': 0.001068551453193082,
#  'ConradNagel': 0.001070762098138275,
#  'AnaïsDemoustier': 0.0010711798926931959,
#  'SarahButler': 0.0010715064628534475,
#  'KathleenBarr': 0.0010727470080403904,
#  'RenatoPozzetto': 0.0010730413671492054,
#  'SabineAzéma': 0.0010770276686623455,
#  'MichelBlanc': 0.0010848015978614039,
#  'LaetitiaCasta': 0.0010858039077904966,
#  'MarcoFerreri': 0.0010858384768110615,
#  'KasiaSmutniak': 0.0010884256482369009,
#  'DeannaDurbin': 0.0010888012245157607,
#  'GuyMarchand': 0.0010911178053046606,
#  "MilesO'Keeffe": 0.0011011039256303833,
#  'MichelDuchaussoy': 0.0011072853467594566,
#  'HaroldS.Bucquet': 0.0011089091763464565,
#  'KimRossiStuart': 0.0011092921750242772,
#  'LesTremayne': 0.0011116942323618785,
#  'MaribelVerdú': 0.0011123871375168844,
#  'KarenMorley': 0.0011168094928386246,
#  'RichardBerry': 0.0011173725498774495,
#  'BernardBlier': 0.0011175136355778034,
#  'BurghartKlaußner': 0.0011191925885986765,
#  'RossydePalma': 0.001119585340240442,
#  'LloydKaufman': 0.001123894858642446,
#  'BertI.Gordon': 0.0011239853905252524,
#  'GiorgiaMoll': 0.0011283421374331478,
#  'LeaMassari': 0.0011286507582551036,
#  'JasonBourque': 0.0011354242171142317,
#  'Jean-PierreLéaud': 0.0011358504421128501,
#  'DenisMénochet': 0.001135989515457069,
#  'LuigiPistilli': 0.0011360510057815778,
#  'GaryYates': 0.0011380872388417752,
#  'RuthDonnelly': 0.0011390266800901073,
#  'JacquesPerrin': 0.0011395751406756147,
#  'LuiseRainer': 0.001141263245776358,
#  'ChristianI.NybyII': 0.0011437494981907524,
#  'EdmundLowe': 0.0011454257867578729,
#  'FredF.Sears': 0.0011474436699098816,
#  'PupiAvati': 0.0011491254169066394,
#  'EmmanuelleDevos': 0.0011514153922117024,
#  'ValerieHobson': 0.0011521605057631026,
#  'GeorgeEastman': 0.0011547858847225758,
#  ...}

# %%
# It seems resonable that directors or actors that appear in a few movies are less connected giving how we calculate these values
dict_director['LotteReiniger']
# Out:
# 15

# %%
# Who are the bridges? 
betweenness_centrality = nx.betweenness_centrality(G)

# %%
betweenness_centrality_order = dict(sorted(betweenness_centrality.items(), key=lambda item: item[1],reverse=True))

# %%
# save graph object to file
pickle.dump(betweenness_centrality, open('betweenness_centrality.pickle', 'wb'))
pickle.dump(eigenvector_centrality_order, open('betweenness_centrality.pickle', 'wb'))

# %%
betweenness_centrality_order
# Out:
# {'ChristopherLee': 0.009365700776509528,
#  'Jr.': 0.0059400973147535775,
#  'DonaldSutherland': 0.005740013017043543,
#  'ErnestBorgnine': 0.005583401927038072,
#  'AnthonyQuinn': 0.005524249696400307,
#  'MalcolmMcDowell': 0.0054121359840835935,
#  'EricRoberts': 0.005185176482905752,
#  'ChristopherPlummer': 0.005113775635694579,
#  'PriyankaChopra': 0.005046653194330893,
#  'MickeyRooney': 0.005016657682630236,
#  'OmPuri': 0.004942240175501012,
#  'MichaelCaine': 0.00492872472890949,
#  'MaxvonSydow': 0.004767852384127542,
#  'GérardDepardieu': 0.004518502679841983,
#  'WillemDafoe': 0.004426361776079331,
#  'EliWallach': 0.004362986698290242,
#  'DeanStockwell': 0.004206023709816889,
#  'RodSteiger': 0.004201825867537865,
#  'CatherineDeneuve': 0.004183197916252519,
#  'RayMilland': 0.004145393206880905,
#  'MichaelMadsen': 0.004027970096465236,
#  'FrancoNero': 0.003944870034935656,
#  'RobertMitchum': 0.003914586717412769,
#  'BruceDern': 0.0038833833835829543,
#  'DonaldPleasence': 0.003725052139013143,
#  'RoddyMcDowall': 0.003658960856721503,
#  'JohnHurt': 0.003614588817415977,
#  'GiancarloGiannini': 0.003559644085347802,
#  'IsabelleHuppert': 0.0035256194340523806,
#  'BruceWillis': 0.003479291168346419,
#  'HarveyKeitel': 0.0034539505173584156,
#  'ChristopherLloyd': 0.0034196665858006355,
#  'MarcLawrence': 0.0033861988687668783,
#  'SamuelL.Jackson': 0.003359700850317266,
#  'GeraldineChaplin': 0.003354591477121641,
#  'ToshirôMifune': 0.0033537113646910045,
#  'JohnMalkovich': 0.003247760411087586,
#  'SeanConnery': 0.003166887758111107,
#  'CharltonHeston': 0.003002234882182587,
#  'SusanSarandon': 0.0029973110675664966,
#  'JohnCarradine': 0.002993174293153654,
#  'ChristopherWalken': 0.002988148266481407,
#  'BurtReynolds': 0.0029832800525808165,
#  'MartinSheen': 0.0029589015757153624,
#  'JamesCaan': 0.002944008687083969,
#  'AnupamKher': 0.0029404704253287333,
#  'RobertDuvall': 0.00288436239325085,
#  'JackieChan': 0.0028695174246986667,
#  'TadanobuAsano': 0.0028362188952235287,
#  'AmrishPuri': 0.0028105258121187125,
#  'HarryDeanStanton': 0.0027996058244191724,
#  'RobertWagner': 0.002702282451991237,
#  'RobertDeNiro': 0.002696046402232557,
#  'JamesMason': 0.0026714791576389436,
#  'HayaoMiyazaki': 0.0026214792605562796,
#  'StellanSkarsgård': 0.0026201281879588826,
#  'JackPalance': 0.0025958060121613986,
#  'RichardHarris': 0.002592710966801774,
#  'NikitaMikhalkov': 0.002591293583342299,
#  'GlennFord': 0.0025634686290847784,
#  'StephenMcHattie': 0.002554578389343172,
#  'JamesCoburn': 0.0025264384469765072,
#  'SteveBuscemi': 0.002517015596781141,
#  'WoodyAllen': 0.0025129917727174625,
#  'ShelleyWinters': 0.0024865623752289697,
#  'LiamNeeson': 0.0024689066629485336,
#  'DennisHopper': 0.0024672002223211564,
#  'VincentPrice': 0.002426517656628132,
#  'RodTaylor': 0.0014538240743634434,
#  'ArmenDzhigarkhanyan': 0.0014283055141623142,
#  'RutgerHauer': 0.0014233558842955535,
#  'RobertLoggia': 0.0014085437408352234,
#  'RalphBellamy': 0.0014066854857287476,
#  'AnushkaShetty': 0.00139805875066748,
#  'IanHolm': 0.0013975925211698425,
#  'SophiaLoren': 0.0013969915916487042,
#  'VladimirMashkov': 0.0013968418745331096,
#  'JeanneMoreau': 0.001384085025946991,
#  'TomHanks': 0.0013840819094169169,
#  'MartinBalsam': 0.001383274250517367,
#  'PeterFonda': 0.0013784051310568772,
#  'FayeDunaway': 0.0013780712861470215,
#  'MathieuAmalric': 0.0013723673191228143,
#  'BarbaraBouchet': 0.001364429260276797,
#  'WilliamHolden': 0.0013578817708781766,
#  'SterlingHayden': 0.0013512308808107895,
#  'JetLi': 0.001341489398074508,
#  'CharlesChaplin': 0.0013368284914101677,
#  'ChristianSlater': 0.0013264742326323296,
#  'AnneBancroft': 0.0013243182878477724,
#  'CiaránHinds': 0.0013189774701329105,
#  'OliverReed': 0.0013187359779193134,
#  'JohnGoodman': 0.0013163999052821747,
#  'ValKilmer': 0.0013156899417343575,
#  'AlainDelon': 0.001315535138097295,
#  'JulianSands': 0.0013149277414188187,
#  'RichardAttenborough': 0.0013149074787980116,
#  'DustinHoffman': 0.0013129706488715569,
#  'KrisKristofferson': 0.0013087464406487056,
#  'MaggieSmith': 0.0013084457853133659,
#  'DebbieReynolds': 0.0013065047699085566,
#  'PeterStormare': 0.0013046434474947388,
#  'JamesWoods': 0.0013025604971578285,
#  'ArthurKennedy': 0.001301765706953865,
#  'NinettoDavoli': 0.001301028646377075,
#  'JeanRochefort': 0.0013005544713347997,
#  'MelFerrer': 0.0012970554257218602,
#  'SeanPenn': 0.0012942007377932233,
#  'ScottGlenn': 0.0012931984837549532,
#  'RobertRedford': 0.001288237477358434,
#  'SamuliEdelmann': 0.0012860473230858068,
#  'JohnHuston': 0.0012799972877417536,
#  'HalHolbrook': 0.0012684130921901513,
#  'TrevorHoward': 0.001262294136505129,
#  'Tabu': 0.001260730480089032,
#  'PaulRudd': 0.0012606942387798845,
#  'SeymourCassel': 0.0012605926503998918,
#  'JoséFerrer': 0.0012596480907668005,
#  'RogerMoore': 0.0012575242972012062,
#  'LeeJ.Cobb': 0.0012566594984684918,
#  'KeithDavid': 0.0012486870663649442,
#  'GeorgeSegal': 0.0012477716902652525,
#  'JeanSimmons': 0.0012469418711394526,
#  'JohnMills': 0.0012442416792330599,
#  'GeorgeKennedy': 0.0012386738896576802,
#  'LeslieNielsen': 0.0012362122122110827,
#  'MarionCotillard': 0.0012355523771622192,
#  'RobertMorley': 0.0012354559048315897,
#  'PeterUstinov': 0.0012332098312025361,
#  'CharlesDurning': 0.0012312042128688327,
#  'SalmaHayek': 0.0012195287110579453,
#  'JohnGielgud': 0.0012192588457684934,
#  'GeorgeSanders': 0.0012181582419675669,
#  'CharlesLane': 0.0012154282096062355,
#  'BernardRose': 0.0012120532456414417,
#  'BillPullman': 0.0012051732984424933,
#  'LambertWilson': 0.0012025487915987988,
#  'LievSchreiber': 0.001200421051417015,
#  'VirginiaMadsen': 0.0011936336979133004,
#  'KieferSutherland': 0.0011875366789741379,
#  'JimBroadbent': 0.0011865920222482852,
#  'M.EmmetWalsh': 0.0011848902175876932,
#  'JamesCromwell': 0.0011773570343633747,
#  'HerbertLom': 0.0011771116054470508,
#  'DavidCross': 0.0011767307694855542,
#  'RobertRyan': 0.0011755538336873715,
#  'StevenSpielberg': 0.001170692548747723,
#  'DonnieYen': 0.0011701940970938094,
#  'HumeCronyn': 0.0011689193536327325,
#  'CarrollBaker': 0.001164219716332042,
#  'MichaelYork': 0.0011597951974564012,
#  'CaryElwes': 0.001159670711407486,
#  'JulianneMoore': 0.0011590498188750482,
#  'JamesHong': 0.0011559145945034314,
#  'EllenBurstyn': 0.0011552620489411274,
#  'NaomiWatts': 0.00115114785893466,
#  'WoodyHarrelson': 0.0011504370274902091,
#  'RayLiotta': 0.0011481245691112281,
#  'RichardWidmark': 0.0011466902733082976,
#  'EdHarris': 0.0011406873351874473,
#  'FrankLangella': 0.0011385397580511885,
#  'CurdJürgens': 0.001137472142580887,
#  'EdLauter': 0.001135753141651742,
#  'SharonStone': 0.0011299186105213264,
#  'WalterMatthau': 0.0011292937155900347,
#  'CameronMitchell': 0.0011245975036383387,
#  'DanielOlbrychski': 0.0011233314562754933,
#  'JohnIreland': 0.001118240629498832,
#  'JoshHartnett': 0.0011181601458940629,
#  'SterlingHolloway': 0.0011162779971250188,
#  'JasonFlemyng': 0.001115797802859399,
#  'KeithCarradine': 0.0011137873888644994,
#  'TimRobbins': 0.0011128573182212153,
#  'OmarSharif': 0.0011126307971220228,
#  'J.K.Simmons': 0.001109188685221289,
#  'JasonRobards': 0.0011063236670146724,
#  'OwenWilson': 0.0011053580851942714,
#  'MarlonBrando': 0.0011019727446666835,
#  'TimRoth': 0.0010984925534526999,
#  'RandyQuaid': 0.001097701980056203,
#  'JohnTravolta': 0.0010841697729963432,
#  'BenStiller': 0.00107804782634723,
#  'DermotMulroney': 0.0010723304501859445,
#  'MichaelLerner': 0.0010711436401846424,
#  'WinonaRyder': 0.0010707106941472643,
#  'EdwardG.Robinson': 0.0010682310557868107,
#  'CateBlanchett': 0.0010679179265924825,
#  'CharlotteGainsbourg': 0.0010662117303398364,
#  'JackWarden': 0.001061884516007995,
#  'Vesa-MattiLoiri': 0.001060345864990146,
#  'JuliaRoberts': 0.0010599955784832283,
#  'GlennClose': 0.0010582419675797775,
#  "VincentD'Onofrio": 0.0010576821738474938,
#  'WalterPidgeon': 0.0010566641942381587,
#  'MichaelGambon': 0.0010520880892018452,
#  'MonicaBellucci': 0.0010520274234114418,
#  'KarenBlack': 0.001050963857302407,
#  'KenWatanabe': 0.001050957030557891,
#  'BruceGreenwood': 0.0010494521969867405,
#  'JamesFox': 0.0010487934112336896,
#  'AleksandrAbdulov': 0.0010484381177089752,
#  'BruceDavison': 0.0010479405927314679,
#  'WilliamShatner': 0.0010445923639429671,
#  'MimiRogers': 0.0008107336611920331,
#  'AndieMacDowell': 0.000810290395057608,
#  'StefaniaSandrelli': 0.0008077944115180978,
#  'JaneAdams': 0.0008025287693241099,
#  'MichaelNyqvist': 0.0008018962065927928,
#  'KirstenDunst': 0.0008015728605431998,
#  'JamesMarsden': 0.0008000749621732818,
#  'JonVoight': 0.0007979145019382049,
#  'GilbertRoland': 0.0007969882906750014,
#  'TakeruSatoh': 0.0007967021540111694,
#  'CliftonCollinsJr.': 0.0007951347939514365,
#  'PamGrier': 0.000792668939635638,
#  'BroderickCrawford': 0.0007891866398975408,
#  'FrankWelker': 0.0007874615339263503,
#  'AngieDickinson': 0.0007834487690600989,
#  'KevinSpacey': 0.0007812407151490953,
#  'BorisKarloff': 0.0007799361862887693,
#  'DrewBarrymore': 0.0007798036487009987,
#  'HowardVernon': 0.00077759208040129,
#  'SallyField': 0.0007760657238498456,
#  'RudolfHrušínský': 0.0007759376904764556,
#  'TreatWilliams': 0.0007754456617028946,
#  'AngelinaJolie': 0.00077476737456245,
#  'EmilyMortimer': 0.00077384897366872,
#  'ClaudeLelouch': 0.0007736910797667559,
#  'PeterLawford': 0.0007732832983771474,
#  'JossAckland': 0.0007729065554831491,
#  'MikaKaurismäki': 0.0007724330659618918,
#  'MarkHamill': 0.000772411671899276,
#  'GretaScacchi': 0.000772285574087402,
#  'JoePantoliano': 0.0007689405639165691,
#  'LukasHaas': 0.0007640365219949186,
#  'AndyLau': 0.0007639487261124703,
#  'DonAmeche': 0.0007632109459960843,
#  'TimCurry': 0.0007625570605874655,
#  'LeslieCaron': 0.0007617728645060244,
#  'FrankSinatra': 0.0007607685373232786,
#  'M.C.Gainey': 0.0007605946177711016,
#  'GeorgeC.Scott': 0.0007603118250226137,
#  'CharlieSheen': 0.0007589662271438443,
#  'F.MurrayAbraham': 0.0007580159351647792,
#  'CarlosAlazraqui': 0.0007571587876993217,
#  'KonstantinKhabenskiy': 0.000754854700595497,
#  'BrunoGanz': 0.00075251766935037,
#  'DavidStrathairn': 0.0007517414469716903,
#  'WilliamFichtner': 0.0007515636844638632,
#  'RichardJaeckel': 0.0007507236474411713,
#  'MichaelAnsara': 0.0007491780014661562,
#  'UmaThurman': 0.000748967619694969,
#  'SeanAstin': 0.0007488118695626346,
#  'Jean-LouisTrintignant': 0.0007446629309355246,
#  'SigourneyWeaver': 0.000744526829754469,
#  'NaseeruddinShah': 0.0007354706324833065,
#  'RaquelWelch': 0.0007347660020738869,
#  'JoeMantegna': 0.000733591584316351,
#  'SallyKellerman': 0.0007318152364107016,
#  'AllisonJanney': 0.0007315158395008924,
#  'AndyDevine': 0.0007314800284502326,
#  'IanWolfe': 0.0007313269276261103,
#  'DianeLane': 0.0007312547526665525,
#  'JamesBrolin': 0.0007305284138211798,
#  'KevinPollak': 0.0007296100767795206,
#  'MillaJovovich': 0.0007294440930199977,
#  'LionelBarrymore': 0.000728358114230427,
#  'LeonardoDiCaprio': 0.000728101926882866,
#  'DenholmElliott': 0.0007274687883644143,
#  'JeanDujardin': 0.00048619044404886236,
#  'DeanMartin': 0.00048516949045976956,
#  'TaliaShire': 0.0004843224089386601,
#  'JoanChen': 0.00048344481585818714,
#  'GeraldineFitzgerald': 0.0004829208938242985,
#  'RyanReynolds': 0.0004828722216487906,
#  'RockHudson': 0.00048237965483707374,
#  'ParkerPosey': 0.00048139755996388694,
#  'RalphRichardson': 0.0004813018584148882,
#  'TimBlakeNelson': 0.0004809412779195626,
#  'CyrilCusack': 0.0004805946594424392,
#  'BillHader': 0.00048030737780704625,
#  'BethGrant': 0.0004798875728111217,
#  'DavidLynch': 0.0004795976242728037,
#  'RadhikaApte': 0.0004786891456942076,
#  'RichardBasehart': 0.0004777362856298875,
#  'MichaelPeña': 0.00047748474935695466,
#  'AkiKaurismäki': 0.0004774150816439291,
#  'WaltDisney': 0.0004754786283200537,
#  'GiancarloEsposito': 0.0004753577595295279,
#  'TimothySpall': 0.0004748517947432934,
#  'Jean-PierreLéaud': 0.00047392124322469156,
#  'GianMariaVolonté': 0.0004732439100659972,
#  'GaryCooper': 0.0004724971760808337,
#  'ToniCollette': 0.0004703730884040491,
#  'EdwardDmytryk': 0.0004703613105708062,
#  'HarryMorgan': 0.0004702187968265768,
#  'DannyAiello': 0.00046976333825209885,
#  'UgoTognazzi': 0.00046932285325516004,
#  'JulienDuvivier': 0.00046788518230014544,
#  'StephenTobolowsky': 0.00046774910005158133,
#  'ChloëSevigny': 0.0004676832257319762,
#  'TabHunter': 0.00046719233520866704,
#  'ChrisPenn': 0.00046683760993482926,
#  'YimouZhang': 0.0004662456342335578,
#  'EvaMendes': 0.0004656396765795287,
#  'LukeWilson': 0.0004655256507336096,
#  'PhilSilvers': 0.00046536053116966235,
#  'EricTsang': 0.00046522873815759065,
#  'AndrewMcCarthy': 0.0004649868674480895,
#  'GusVanSant': 0.0004649740548867409,
#  'LuisTosar': 0.0004633901148201005,
#  'AdamWest': 0.0004633651041969781,
#  'MarcBlucas': 0.0004632617087276535,
#  'VictorJory': 0.00046317687472938076,
#  'GiovanniRibisi': 0.00046277898535882595,
#  'LilyTomlin': 0.0004613958527169138,
#  'IanMcKellen': 0.00046110582692626543,
#  'HankAzaria': 0.0004608339413867204,
#  'DickMiller': 0.0004603503389560835,
#  'LinusRoache': 0.0004597795926361342,
#  'BillNighy': 0.0004597217024648247,
#  'BlakeEdwards': 0.00045924065362910275,
#  'EmmaThompson': 0.00045717828849969997,
#  'HectorElizondo': 0.0004568223981775938,
#  'RitaHayworth': 0.00045680354802095293,
#  'VittorioDeSica': 0.00045674056053220666,
#  'BudSpencer': 0.00045658486251141386,
#  'HalleBerry': 0.0004558202471135149,
#  'FredWillard': 0.000454887984402217,
#  'AlbertFinney': 0.0004542665038672205,
#  'GérardDarmon': 0.00045404955668731093,
#  'JeremyPiven': 0.0004538037872307845,
#  'AkiraKamiya': 0.00045374413507338706,
#  'AlfredHitchcock': 0.0004537356873034422,
#  'DanielCraig': 0.000453278611947545,
#  'BillyBobThornton': 0.0004529331622318973,
#  'IsaachDeBankolé': 0.00045273873329830814,
#  'RoseByrne': 0.0004521828224096275,
#  'FredricMarch': 0.0004516264822806317,
#  'VinceVaughn': 0.0004513304606705964,
#  'MichaelClarkeDuncan': 0.0004478686756797135,
#  'JonFavreau': 0.00044778185152457737,
#  'GloriaStuart': 0.00044657416372757694,
#  'RubyDee': 0.000446404522103595,
#  'MorganFairchild': 0.00044625500529750305,
#  'BryanCranston': 0.0004457160900228906,
#  'CameronDiaz': 0.00044521336657000164,
#  'JosephSargent': 0.0004452060636385669,
#  "MaureenO'Hara": 0.0004450917774870951,
#  'BipashaBasu': 0.00044496066579339334,
#  'NikolajLieKaas': 0.0004447993128490178,
#  'MadsMikkelsen': 0.00044388485357986957,
#  'AdolpheMenjou': 0.0004436334836437465,
#  'CaroleBouquet': 0.0004423961463540796,
#  'JimCarrey': 0.0004419766882148903,
#  'EdwardAsner': 0.0004418218688835868,
#  'MaryWoronov': 0.0004416069243396938,
#  'ColinFarrell': 0.00044095228951525453,
#  'JohnnyHallyday': 0.0004402452376539002,
#  'JamesGandolfini': 0.0004397479908726817,
#  'BuntaSugawara': 0.00043910666423262694,
#  'FrancisFordCoppola': 0.00043896786205789595,
#  'GwynethPaltrow': 0.0004379444639111352,
#  'TerenceYoung': 0.00043780395372360097,
#  'JuddNelson': 0.00043699411196826513,
#  'CynthiaRothrock': 0.00043639370442816026,
#  'OssieDavis': 0.00043634029539410264,
#  'MichaelCurtiz': 0.00043561002634630384,
#  'BéréniceBejo': 0.0004352792634907514,
#  'HumphreyBogart': 0.00043491402943200566,
#  'FannyArdant': 0.0004345668868884701,
#  'GuyMadison': 0.00043391975448466296,
#  'ShimaIwashita': 0.0004328659834184167,
#  'KevinCostner': 0.0004327929412173088,
#  'PatrickWarburton': 0.00043229339009983394,
#  'HenryHull': 0.0004317305942915958,
#  'KateWinslet': 0.00043160864714622706,
#  'DirkBogarde': 0.00043155859830921924,
#  'TildaSwinton': 0.0004313527476740135,
#  'BobBalaban': 0.00043024010618995085,
#  'KenAnnakin': 0.0004293843955918133,
#  'ChristinaApplegate': 0.00042911886070214094,
#  'LochlynMunro': 0.0004289056014583529,
#  'CarolineMunro': 0.00042795900923473385,
#  'PaulFix': 0.0004273239680150283,
#  'MauroBolognini': 0.00042491087896428295,
#  'DavidDencik': 0.0004248408450861266,
#  'JohnSteiner': 0.00042436190651845454,
#  'JudyGreer': 0.00042432606648165,
#  'DarrenMcGavin': 0.00042399573321707916,
#  'YvonneDeCarlo': 0.0004236801172406933,
#  'CharlesS.Dutton': 0.0004231490353852282,
#  'JenniferConnelly': 0.00042272151612621943,
#  'KathleenQuinlan': 0.0004226777121086395,
#  'StephenBaldwin': 0.0004219271636896479,
#  'FrancesFisher': 0.0004217387132949283,
#  'ElizabethBanks': 0.00042155361110815114,
#  'HarrisYulin': 0.0004214392561770283,
#  'OttoPreminger': 0.0004212439455306901,
#  ...}

# %% [markdown]
# Giving the big diameter and the low clustering, it seems like this parameter is very important. So this actor **Christopher Lee** Connects different groups of actors and directors.
